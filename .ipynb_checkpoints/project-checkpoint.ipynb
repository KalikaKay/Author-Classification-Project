# %% [markdown]
# # Author Classification Project
#
# *a thinkful project by Kalika Kay Curry*
#
# Build a project to classify text-author.
#
# Collect thousand texts from Gutenberg project (and 7 novels) for at least 10 authors.

# %%
from urllib import request
import pandas as pd
import en_core_web_sm
import nltk
from nltk.corpus import gutenberg
import re
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
import datetime as dt
import seaborn as sns
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import plotly.express as px
import pickle
import joblib
from sklearn.metrics import classification_report
import numpy as np

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import ComplementNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

#Where the pickle file is stored. 
filename = "..\d_store\data.pkl"

# %%
# Utility function for standard text cleaning
def text_cleaner(text):
    # Visual inspection identifies a form of punctuation that spaCy doesn't
    # recognize: the double dash --. Better get rid of it now!
    text = ' '.join(text.split())
    text = re.sub(r"\r?\n|\r", " ", text)
    text = re.sub(r'--',' ',text)
    text = re.sub(r"(\b|\s+\-?|^\-?)(\d+|\d*\.\d+)\b", " ", text)
    text = re.sub("[\[].*?[\]]", "", text)
    return text

# %%
def length_frequencies(text):
    length = [len(w) for w in text]
    fdist = nltk.FreqDist(length)
    return fdist

# %%
# Utility function to calculate how frequently words appear in the text
def word_frequencies(text):
    
    # Build a list of words
    # Strip out punctuation
    words = []
    for token in text:
        if not token.is_punct:
            words.append(token.text)
            
    # Build and return a `Counter` object containing word counts
    return Counter(words)

# %%
def timer(text):
    print(f'{dt.datetime.now().strftime("%d/%m/%Y %H:%M:%S")}: {text}')

# %%
# model_tuples = [    ('nb', ComplementNB()),
#                     ('rf', RandomForestClassifier(random_state=1)), 
#                     ('lr', LogisticRegression()),
#                      ('gb', GradientBoostingClassifier()),
#                      ('knn', KNeighborsClassifier()),
#                      ('sv', SVC()),
#                      ('dt', DecisionTreeClassifier()) 
#                ]
# model_parms = ['', rfp, lrp, gbp, knnp, svp, dtp]               
def model_data(model_name, model_parms, model_tuple, n_jobs=1):
    pipeline = Pipeline([('vectorizer', CountVectorizer(analyzer='word')), model_tuple])
    params = vr.copy()
    params.update(model_parms)
    search = GridSearchCV(pipeline, params, cv=cv, verbose=True, n_jobs=n_jobs)
    print(f'{dt.datetime.now().strftime("%d/%m/%Y %H:%M:%S")}, started {model_name} grid search')
    search.fit(X_train.astype(str), y_train)
    print(f'{dt.datetime.now().strftime("%d/%m/%Y %H:%M:%S")}, {model_name} grid search complete')
    
    bow_model = search.best_estimator_

    bow_model.fit(X_train, y_train)
    y_pred = bow_model.predict(X_test)
    
    print(classification_report(y_test, y_pred))

# %%
def listtostrings(s):
    return ' '.join([str(elem) for elem in s])

# %%
#Thousands of Gutenberg texts.
print(f'{dt.datetime.now().strftime("%d/%m/%Y %H:%M:%S")}, started')
text2000 = []
i = 9
count = 0
while count != 2000:    
    try:
        url = f'http://www.gutenberg.org/files/{i}/{i}.txt'
        response = request.urlopen(url)
        raw = response.read().decode('utf8')
        text2000.append(raw )
        count += 1
        i += 1
    except:
        i += 1
print(f'{dt.datetime.now().strftime("%d/%m/%Y %H:%M:%S")}, ended')
# Out:
# 27/12/2020 14:24:57, started
# 27/12/2020 14:47:33, ended

# %% [markdown]
# # Authors
#
# The texts from the Gutenberg library does not provide authors in a seperate field. Even the html files don't contain a seperate author field for identifying, easily, who the work is by; so I can't really run a classifier on this yet.
#
# At the same time, I'm curious who these 2,000 works are by - how many of each author do I have? So a little bit of data exploration and preprocessing to get the authors.

# %% [markdown]
# From working with gutenberg data in previous examples, I know that most authors appear within the first 150 characters of the text. Usually it's less than 150 characters, somewhere in the 75 character range. I want the first 150 characters because of this.

# %%
#Authors names usually appear within the first 150 characters. 
authors = []
for text in text2000:
    authors.append(text_cleaner(text[0:150]))
print(authors[10:15])
# Out:
# ["The Project Gutenberg EBook of Roget's Thesaurus, by Peter Mark Roget This eBook is for the use of anyone anywhere at no cost and with almost no r", 'The Project Gutenberg EBook of The Narrative of the Life of Frederick Douglass, by Frederick Douglass This eBook is for the use of anyone anywhe', 'The Project Gutenberg EBook of O Pioneers!, by Willa Cather This eBook is for the use of anyone anywhere at no cost and with almost no restriction', 'The Project Gutenberg EBook of The CIA World Factbook, by United States. Central Intelligence Agency. This eBook is for the use of anyone a', 'The Project Gutenberg EBook of Paradise Lost, by John Milton ******************************************************************* THIS EBOOK WAS']

# %%
#Authors will appears after the word "by"
tokens = nltk.word_tokenize(listtostrings(authors))
authortext = nltk.Text(tokens)

#abandoing this method for - reasons.
first = nltk.text.ConcordanceIndex(authortext).offsets('by') 
example = []
for x in first:
    example.append(authortext[x+1])
print(example[0:15])
# Out:
# ['Abraham', 'Charles', 'Lewis', 'United', 'James', 'Anonymous', 'Alexander', 'Henry', 'John', 'Peter', 'Frederick', 'Willa', 'United', 'John', 'Thomas']

# %%
#Looking at how often the words Gutenberg and by appear in the text.
authortext.dispersion_plot([' by ', 'Gutenberg', 'Anonymous', 'Various', 'This', 'Author'])

# %%
authortext.concordance('Gutenberg')
# Out:
# Displaying 25 of 2007 matches:
# The Project Gutenberg EBook of Lincoln 's First Inaugura
#  of anyone anywhere a ﻿The Project Gutenberg EBook of The King James Bible * *
#  * EBOOK ( # ) WAS ONE The Project Gutenberg EBook of Through the Looking-Glass
# eBook is for the use o The Project Gutenberg EBook of The Hunting of the Snark
# o cost and with almost The Project Gutenberg EBook of The CIA World Factbook ,
# r the use of anyone an The Project Gutenberg EBook of Peter Pan , by James M. B
# h almost no restrictio The Project Gutenberg EBook of The Book Of Mormon , by A
# with almost no restric The Project Gutenberg EBook of The Federalist Papers , b
# r the use of anyone an The Project Gutenberg EBook of The Song Of Hiawatha , by
# no cost and with almos The Project Gutenberg EBook of Paradise Lost , by John M
# h almost no restrictio The Project Gutenberg EBook of Roget 's Thesaurus , by P
# t and with almost no r The Project Gutenberg EBook of The Narrative of the Life
# e use of anyone anywhe The Project Gutenberg EBook of O Pioneers ! , by Willa C
#  almost no restriction The Project Gutenberg EBook of The CIA World Factbook ,
# or the use of anyone a The Project Gutenberg EBook of Paradise Lost , by John M
# * * * * THIS EBOOK WAS The Project Gutenberg EBook of Far from the Madding Crow
#  * * * * * * * * * THI The Project Gutenberg EBook of Aesop 's Fables , by Aeso
# ost no restrictions wh The Project Gutenberg EBook of Census of Population and
# k is for the use of anyone Project Gutenberg 's The Bible , King James Version
# ost and with almost no The Project Gutenberg EBook of The Oedipus Trilogy , by
#  with almost no restri The Project Gutenberg EBook of Herland , by Charlotte Pe
# no cost and with almos The Project Gutenberg EBook of The Scarlet Letter , by N
# at no cost and with almost Project Gutenberg 's Zen and the Art of the Internet
# cost and with almost n The Project Gutenberg EBook of The War of the Worlds , b
#  and with almost no re The Project Gutenberg EBook of Census of Population and

# %%
#This is the best that I can do. 
name = []
for x in authors:
    first = x.find('by') + len('by ')
    last = x.find('This') 
    if last == -1:
        last = x.find('*')
    name.append(text_cleaner(x[first:last].strip("*")))
print(name[0:25])
# Out:
# ['Abraham Lincoln', 'he Project Gutenberg EBook of The King James Bible', 'Charles Dodgson AKA Lewis Carroll', 'Lewis Carroll', 'United States. Central Intelligence Agency', 'James M. Barrie', 'Anonymous', 'Alexander Hamilton and John Jay and James Madison', 'Henry W. Longfellow', 'John Milton', 'Peter Mark Roget', 'Frederick Douglass', 'Willa Cather', 'United States. Central Intelligence Agency.', 'John Milton', 'Thomas Hardy', 'Aesop', 'United States Bureau of the Census', 'Various', 'Sophocles', 'Charlotte Perkins Stetson Gilman', 'Nathaniel Hawthorne', 'Brendan P. Kehoe', 'H. G. Wells', 'United States Bureau of the Census']

# %%
d = { 'author': name, 'text': text2000}
df = pd.DataFrame(d)

# %%
#Clean the text, like for authors.
df['text'].apply(lambda x: text_cleaner(x))
df.head()
# Out:
#                                               author  \
# 0                                    Abraham Lincoln
# 1  he Project Gutenberg EBook of The King James B...
# 2                  Charles Dodgson AKA Lewis Carroll
# 3                                      Lewis Carroll
# 4         United States. Central Intelligence Agency
#
#                                                 text
# 0  The Project Gutenberg EBook of Lincoln's First...
# 1  ﻿The Project Gutenberg EBook of The King James...
# 2  The Project Gutenberg EBook of Through the Loo...
# 3  The Project Gutenberg EBook of The Hunting of ...
# 4  The Project Gutenberg EBook of The 1990 CIA Wo...

# %%
df[df.author == '']
# Out:
#      author                                               text
# 329          ***The Project Gutenberg Etext of The Hymns of...
# 352          **The Project Gutenberg Etext of The Crowd, by...
# 355          **The Project Gutenberg Etext of The Psycholog...
# 356          ****The Project Gutenberg Etext of Pathology o...
# 361          ***The Project Gutenberg Etext of "The Breitma...
# ...     ...                                                ...
# 1835         \r\n\r\n\r\n\r\n******************************...
# 1896         **This is a COPYRIGHTED Project Gutenberg Etex...
# 1985         ***Project Gutenberg Etext: The Circus Boys Ac...
# 1986         ***Project Gutenberg Etext: The Circus Boys In...
# 1995         **The Project Gutenberg Etext of Moby Dick, by...
#
# [136 rows x 2 columns]

# %%
#Drop authors that haven't been parsed. 
df.author.replace('', float("NaN"), True)
df.dropna(inplace=True)

# %%
#Update some names. 
pd.options.display.max_seq_items = 1000
df.author.value_counts().index
# Out:
# Index(['Honore de Balzac', 'Richard Harding Davis', 'Thomas Carlyle', 'Plato',
#        'Jack London', 'Joseph Conrad', 'Henry James', 'Various',
#        'Arthur Conan Doyle', 'Anonymous', 'Edgar Rice Burroughs',
#        'Charles Dickens', 'Jerome K. Jerome',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works',
#        'Bret Harte', 'Wilkie Collins', 'L. Frank Baum',
#        'Robert Louis Stevenson', 'Victor Appleton', 'Xenophon',
#        'Mary Roberts Rinehart', 'Unknown', 'Rudyard Kipling', 'H. G. Wells',
#        'Nathaniel Hawthorne', 'Kate Douglas Wiggin', 'Zane Grey',
#        'Jules Verne', 'Edith Wharton', 'Booth Tarkington', 'Sir Walter Scott',
#        'Robert Nemiroff and Jerry Bonnell', 'E. Phillips Oppenheim',
#        'Andrew Lang', 'Frances Hodgson Burnett', 'Owen Wister',
#        'Alice Meynell', 'Max Beerbohm', 'Thomas Babington Macaulay',
#        'Thomas Bailey Aldrich', 'B. M. Bower', 'George Bernard Shaw',
#        'Thomas Hardy', 'George MacDonald', 'O. Henry', 'Sax Rohmer', 'Virgil',
#        'Charles Darwin', 'John Milton', 'Washington Irving', 'Jane Austen',
#        'William Makepeace Thackeray', 'William Shakespeare',
#        'David Graham Phillips', 'Leo Tolstoy', 'Anthony Trollope',
#        'Lucy Maud Montgomery', 'United States. Central Intelligence Agency.',
#        'Willa Cather', 'Edna Ferber', 'H. Rider Haggard', 'Oscar Wilde',
#        'G. K. Chesterton', 'United States', 'E. Nesbit',
#        'William Dean Howells', 'Edward Gibbon', 'Joseph C. Lincoln',
#        'Benedict de Spinoza', 'Charles Kingsley', 'Horatio Alger',
#        'G.K. Chesterton', 'Frank Norris', 'J. M. Synge',
#        'Herbert George Wells', 'Dante Alighieri',
#        'Robert Louis Stevenson, Edited by Sidney Colvin', 'Anton Checkov',
#        'Stewart Edward White', 'Sara Teasdale', 'Howard Pyle',
#        'James Fenimore Cooper', 'George Eliot', ', Charles A. Eastman',
#        'Eleanor H. Porter', 'Horatio Alger, Jr.', 'Robert W. Service',
#        'Emile Gaboriau', 'George Borrow', 'Henry Lawson',
#        'Gene Stratton-Porter', 'William MacLeod Raine', 'Olive Schreiner',
#        'Benedict of Spinoza', 'Stanley Weyman', 'E. W. Hornung',
#        'Daniel Defoe', 'Edgar Allan Poe', 'Henry Smith Williams',
#        'Martin Luther', 'Henry van Dyke', 'Don Marquis', 'Gaston Leroux',
#        'Rafael Sabatini', 'Edward Bulwer Lytton', 'Charles Reade',
#        'Gustave Flaubert', 'Thornton W. Burgess', 'Amy Lowell',
#        'Anna Katharine Green', 'William Morris', 'Frederick Douglass',
#        'Albert Payson Terhune', 'Joseph Sheridan Le Fanu', 'Ambrose Bierce',
#        'Gene Stratton Porter', 'Samuel Smiles', 'Vachel Lindsay',
#        'John Buchan', 'Rebecca Harding Davis', 'Alphonse Daudet',
#        'Samuel Butler', 'Stephen Crane', 'Kenneth Grahame',
#        'Andrew Barton 'Banjo' Paterson', 'Edwin Arlington Robinson',
#        'Edna Lyall', 'Ernest Bramah', 'J. M. Barrie', 'Herbert A. Giles',
#        'P. G. Wodehouse', 'Henrik Ibsen', 'Anton Chekhov',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyright law',
#        'Alexander Whyte', 'Charles Mackay', 'Irvin S. Cobb',
#        'Charles Dickens, et al', 'Ulysses S. Grant', 'John Galt', 'Herodotus',
#        'Horatio Alger Jr.', 'Saki',
#        'Robert Louis Stevenson and Lloyd Osbourne', 'William Blake',
#        'John Greenleaf Whittier',
#        'Susan Fenimore Cooper Volume Copyright laws are changing all over the world, be sure to check the co',
#        'Sara Cone Bryant', 'Mark Twain', 'Mark Twain (Samuel Clemens)',
#        'Augusta Groner', 'Elia W. Peattie',
#        'United States Bureau of the Census', 'Charles Brockden Brown',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyright l',
#        'Frank Stockton', 'Jean Armour Polly', 'Richard Jefferies',
#        'Anatole France', 'Ernest Thompson Seton', 'Donald Ogden Stewart',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyright laws are changin',
#        'Jean Webster', 'An Imitator of Plato', 'Louisa May Alcott',
#        'Frank L. Packard', 'Tobias Smollett',
#        'Thackeray # in our series by William Makepeace Thackeray Copyright laws are changing al',
#        'Frank R. Stockton', 'Walter Pater', 'Edna St. Vincent Millay',
#        'George Meredith', 'Anthony Hope', 'Algernon Charles Swinburne',
#        'Susan Fenimore Cooper', 'Bram Stoker', 'Lytton Strachey',
#        'Maxim Gorky',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyright laws are c',
#        'Aristotle', 'Thomas Wentworth Higginson', 'Ellis Parker Butler',
#        'Ludwig van Beethoven', 'Thomas Henry Huxley', 'Sophocles',
#        'Louis Ginzberg Copyright laws are changing all over the world, be sure to ch',
#        'Edgar A. Guest', 'William Wells Brown', 'W. Somerset Maugham',
#        'or about Honore de Balzac Copyright laws are changing al',
#        'Theodore Dreiser', 'Lewis Carroll', 'Isaac Taylor Headland',
#        'Harold Frederic', 'John Fiske', 'Japan', 'Virginia Woolf',
#        'Mary E. Wilkins Freeman', 'Francis Thompson',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyright laws are ch',
#        'Oliver Wendell Holmes, Jr.', 'Christopher Morley',
#        'Henry Wadsworth Longfellow', 'Amelia E. Barr', 'Andrew Steinmetz',
#        'Laura Lee Hope', 'Maria Edgeworth',
#        'Grace Isabel Colbron and Augusta Groner',
#        'United States Central Intelligence Agency', 'Alexis de Toqueville',
#        'James Whitcomb Riley Copyright laws are changin', 'Edmund Venables',
#        'Epictetus', 'Ida Pfeiffer', '(His Son) Captain Robert E. Lee',
#        'Greg Fee', 'John Keats', 'Thomas De Quincey',
#        'Thomas A Kempis Copyright laws are changing all over the world, be sure to check the copyright',
#        'James Lane Allen Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Robert F. Murray, Edited by Andrew Lang', 'H. Stanley Redgrove',
#        'Henry Wadsworth Longfellow Copyright laws are changing all over',
#        'Adelaide Anne Procter', 'Samuel Taylor Coleridge',
#        'United States National Aeronautics and Space Administration',
#        'Howard Trueman Copyright laws are changing all over the world, be sure to c',
#        'B. Perez Galdos', 'John Farrar', 'William Blades',
#        'Arthur Brisbane # in our series by Arthur Brisbane Copyright laws a',
#        'Lao-Tze', 'Leo Tolstoi', 'John Bunyan', 'Maurice LeBlanc',
#        'Hale Copyright laws are changing all over the world, be sure to check the copyright',
#        'John Fox', 'Harry Alonzo Cushing, vol. III. Copyright laws are cha',
#        'Voltaire, Edited by Henry Morley', 'Edmund G. Ross',
#        'Adam Lindsay Gordon', 'Brian Oswald Donn-Byrne',
#        'William and Ellen Craft Copyright laws are changing all over the world, be s',
#        'Frank Lewis Dyer and Thomas Commerford Martin', 'Robert Service',
#        'Dornford Yates', 'Victor MacClure', 'The National Atomic Museum',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyright laws are',
#        'Ellen Robena Field', 'Elbert Hubbard',
#        'Joanot Martorell and Marti Johan d'Galba', 'William Hazlitt',
#        'Arthur B. Reeve Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Homer and Hesiod', 'William Hickling Prescott',
#        'Cunninghame Graham Copyright laws are changing all over the world, be sure to check the copyright',
#        'e Project Gutenberg Etext of The Journal of Abnormal Psychology Copyright laws are changing all over the world, be sure to check the copyright',
#        'Stephen Vincent Benet', 'Edward Everett Hale', 'Maynard Barbour',
#        'United States Arms Control and Disarmament Agency',
#        'Jean Baptiste Racine', 'Coalition for Networked Information',
#        'oject Gutenberg Etext of Autobiography of Andrew Dickson White # in our series Andrew Dickson White We are counting both volumes as # in our',
#        'by (AKA B. M. Sinclair) B. M. Bower', 'Lewis Roth',
#        'A.C. Seward and Others', 'Valentine Williams', 'Sherwood Anderson',
#        'Sara Jeanette Duncan', 'Elbridge S. Brooks', 'Charles Babbage',
#        'Frances Bacon', 'John Murray and Mills Miller', 'Peter Mark Roget',
#        'Edward P. Roe', 'Henry Cabot Lodge, and Theodore Roosevelt',
#        'Jack London # - in our series by Jack London Copyright laws are changing all over the wo',
#        'Thomas Alexander Browne, AKA Rolf Boldrewood',
#        'Frances Hodgson Burnett, Illustrated by F. C. Yohn', 'Henry Clay',
#        'Richard Lovelace', 'A. O. Brownson', 'John Fox, Jr.', 'Calamity Jane',
#        'H. B. Irving', 'Stan Kerr', 'S. Weir Mitchell', 'Hendrik van Loon',
#        'Joe Hutsko', 'Ivan S. Turgenev', 'William H. Prescott',
#        'Louise Muhlbach', 'Abraham Lincoln', 'Thomas Dixon', 'Baruch Spinoza',
#        'Alice Dunbar', 'Giambattista Basile',
#        'William Wells Brown ( edition) See Apr Clotelle; or The Colored Hero',
#        'Henry James # in our series by Henry James', 'Edward Carpenter',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyright laws are chang',
#        'Harriet E. Wilson', 'Andrew Lang, Edited by W. H. Davenport Adams',
#        'G. Harvey Ralphson', 'Ruth Ogden', 'David Slowinski',
#        'Chester K. Steele', 'Edmund Burke, Edited by Henry Morley',
#        'William Smith', 'Martin Luther, translated by Robert E. Smith.',
#        'Charles Dodgson AKA Lewis Carroll', 'Apollonius Rhodius',
#        'Julian Hawthorne Copyright laws are changing all over the world, b',
#        'United States Army',
#        'Jerome K. Jerome # in our series by Jerome K. Jerome Copyright laws are changing all over th',
#        'William D. McClintock and Porter Lander McClintock Copyright laws are chang',
#        'F. Hopkinson Smith', 'Richard le Gallienne', 'Thomas Hart Benton',
#        'Winn Schwartau', 'Burbank L. Todd', 'Herbert Allen Giles',
#        'George Borrow, Illustrated by E. J. Sullivan', 'Earl Derr Biggers',
#        'A. J. O'Reilly', 'Joyce Kilmer', 'Henry Van Dyke', 'E. Charles Vivian',
#        'Fulgence Marion',
#        'oject Gutenberg Etext of Sir Thomas More ascribed in part to Shakespeare PG has multiple editions of William Shakespeare's Complete Works',
#        'Ayn Rand******* # in our series by Ayn Rand', 'Homer',
#        'Mary Eleanor Wilkins Freeman',
#        'Johanna Spyri =========================================================================== There are sever',
#        'Alexandre Dumas, fils', 'Prosper Merimee', 'Smyrnaeus Quintus',
#        'Samuel White Baker', 'Cal Stewart', 'John Gower',
#        'General William Booth [ The founder of the Salvation Army tells of his philoso',
#        'John William Draper', 'James Stephens',
#        'George M. Gould and Walter Lytle Pyle', 'Alice Freeman Palmer',
#        'sinia, by Jerome Lobo, Edited by Henry Morley, Translated by Samuel Johnson',
#        'R. M. Ballantyne, Illustrated by Dalziel', 'P. J. Proudhon',
#        'Ellen Key', 'John McCrae',
#        'Stephen Crane # in our series by Stephen Crane Copyright laws are changing all over the worl',
#        'Diane and Don Nafis, dnafis@nazlo.com The Project Gutenberg Etext of James Otis The Pre-Revolutionist by John Clark Ridpath Co',
#        'Eros Urides and J. L. Kennon',
#        'onia and Assyria, by Theophilus G. Pinches', 'Odd de Presno',
#        'Maurice Maeterlinck Copyright laws are changing all over the world, be sure to check the copyright',
#        'Richard F. Burton', 'Chretien de Troyes',
#        'Grace Isabel Colbron, and Augusta Groner', '(may be spurious) Plato',
#        'Marie L. McLaughlin', 'Karl Marx',
#        'William Shakespeare Copyright laws are changing all over the world. Be sure to chec',
#        'J. M. Synge # in our series by J. M. Synge Copyright laws are changing all over the world',
#        'English Authors: Africa, by Various',
#        'Pi (to million digits), by Yasumasa Kanada', 'Isabella L. Bird',
#        'Margaret Deland', 'Alexandre Dumas, Pere', 'Margaret Hill McCarter',
#        'Miriam Michelson', 'Lafcadio Hearn', 'Madame de La Fayette',
#        'Frances Jenkins Olcott',
#        'Martin Luther # in our series by Martin Luther Copyright laws are changing all over the wor',
#        'George Whale',
#        'Bishop Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Hjalmar Hjorth Boysen',
#        'Henry Wadsworth Longfellow Copyright laws are changing all ove',
#        'J. Walker McSpadden', 'C. F. Volney', 'Wilfred Owen',
#        'Charlotte Perkins Stetson Gilman', 'Robert Southey', 'James Boswell',
#        'Elizabeth Gaskell # in our series by Elizabeth Gaskell Copyright laws are changing all over th',
#        'Aesop', 'Martha Young', 'Maria Edgeworth, Edited by Henry Morley',
#        'LeFebure', 'Robert Williams Wood', 'Robert Hichens',
#        'Fannie Isabelle Sherrick Copyright laws are changing all over the world, be sur',
#        'he Project Gutenberg EBook of The King James Bible',
#        'Joshua Reynolds, Edited by Henry Morley',
#        'Kate Douglas Smith Wiggin, Illustrated by Claude A. Shepperson',
#        'Julian Hawthorne PART I DETECTIVE STORI', 'Katherine Mansfield',
#        'Lodovico Ariosto', 'William Dobein James', 'Herbert Darling Foster',
#        'Charles Whibley', 'United States. Central Intelligence Agency',
#        '(AKA Ralph Iron) Olive Schreiner', 'Nikolai Vasilievich Gogol',
#        'St. Jude, R. U. Sirius, Bart Nagel', 'ENTY YEARS AFTER',
#        'Marie Belloc Lowndes', 'E. H. Chapin', 'Mary Johnston',
#        'Mary Murdoch Mason',
#        'oject Gutenberg Etext Increasing Human Efficiency In Business Copyright laws are changing all over the world, be sure to check the copyright',
#        'Enrico Ferri', 'Mr. and Mrs. Haldeman-Julius', 'Lord Dunsany',
#        'oject Gutenberg Etext Use and Need of the Life of C. A. Nation Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Walter Scott', 'Edward S. Ellis et. al.', 'Edward Lear',
#        'Snorri Sturlason',
#        'John Lord Copyright laws are changing all over the world. Be sure',
#        'Eliot Gregory',
#        'Macaulay # in our series by Thomas Babington Macaulay Copyright laws a',
#        'Max Brand', 'Karl Marx and Friedrich Engels', 'Charles W. Chesnutt',
#        'oject Gutenberg Etext The Lock and Key Library, Hawthorne, Ed. Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'e Project Gutenberg EBook of Remarks of Mr. Calhoun of South Carolina on the bill to prevent the interference of certain federal officers in elect',
#        'John Lord Copyright laws are changing all over the world. Be sure t',
#        'Rupert Brooke', 'Conrad Aiken', 'Robert Graves',
#        'William Roscoe Thayer Copyright laws are changing all over the world, be s',
#        'Henry Timrod', 'Freeman Wills Crofts', 'Emma Goldman',
#        'David Magie Cory',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyrig',
#        'Madame de Lafayette', 'Etienne Leon Lamothe-Langon',
#        'e Project Gutenberg Etext of Popular Science Monthly Volume Copyright laws are changing all over the world, be sure to check the copyrig',
#        '(AKA Clive Hamilton) C. S. Lewis', 'Francis Parkman, Jr.',
#        'Harriet Beecher Stowe', 'Russell H. Conwell', 'Frank Frankfort Moore',
#        'J. Stark Munro',
#        'e Project Gutenberg Etext Divina Commedia di Dante: Purgatorio In Italian with no accents Please see my notes about various versions',
#        'Frank Tymon', 'by Edward Jenkins', 'J. Storer Clouston',
#        'John A. Carpenter', 'Dan Scavelle', 'by Charles Dickens',
#        'Thomas Papanikolaou', 'Guy de Maupassant', 'Hall Caine',
#        'oject Gutenberg Etext of Study of the King James Bible, McAfee',
#        'Mitzi Perdue', 'Margaret Sanger', 'Robert Harris',
#        'MICRA, Inc. Copyri', 'Royall Tyler', 'Henry H. Snelling',
#        'Jeffery Farnol', 'Henry Adams', 'William Godwin',
#        'Carl Maag and Steve Rohrer', 'Dinah Maria Mulock Craik',
#        'William Beckford, Edited by Henry Morley', 'John Masefield',
#        'David Livingstone',
#        'Wagner/Burgoyne The author catalog entries are rather strange, so we included an assortment of inf',
#        'Alexander Pope, Edited by Henry Morley', 'Helen Cody Wetmore',
#        'the Lambs', 'Jonathan Swift', 'J. M. Bacon',
#        'Elizabeth Cleghorn Gaskell', 'Ruth M. Sprague', 'Alfred Joyce Kilmer',
#        'Jean Clottes',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyrigh',
#        'Andy Adams', 'Walter Raleigh',
#        '(AKA Charlotte, Emily and Anne Bronte) Currer, Ellis, and Acton Bell',
#        'Jerome K. Jerome, Illustrated by A. Frederics', 'Benjamin Cardozo',
#        'Michael Husted', 'Wu Tingfang', 'Norman F. Joly', 'Sarojini Naidu',
#        'Samuel Johnson',
#        'Justus Friedrich Karl Hecker, Edited by Henry Morley, Translated by Benjami',
#        'Alfred Tennyson', 'Jerry Bonnell and Robert Nemiroff', 'Zitkala-Sa',
#        'Frederick A. Talbot', 'Willa Cather and Alfred Noyes', 'H. L. Mencken',
#        'L. Cranmer-Byng Please take a look at the important information in this header. We encourage you',
#        'Anna Katherine Green',
#        'Thackeray # in our series by William Makepeace Thackeray Copyright laws are changing a',
#        'Ellen Glasgow Copyright laws are changing all over the worl',
#        'John Webster', 'Beatrix Potter', 'Tadashi Nakashima',
#        'Natalie Sumner Lincoln', 'Gertrude Atherton', 'E. F. Benson',
#        'Alexandre Dumas (Pere)', 'George Sand', 'Friedrich Schiller',
#        'James Russell Lowell', 'Thomas Jefferson', 'Owen Meredith',
#        'H. Rider Haggard # in our series by H. Rider Haggard', 'Thoma',
#        'Rudge, by Charles Dickens', 'William Congreve, Edited by G. S. Street',
#        'Jack London, Illustrated by Charles Livingston Bull',
#        'Carvalho Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Jeffrey Farnol',
#        'Tilden Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Lucius Apuleius',
#        'sinia, by Baker Copyright laws are changing all over the world, be sure to check the copyright la',
#        'Thomas More, Edited by Henry Morley', 'Anna Howard Shaw',
#        '(AKA Elia Wilkinson) Elia W. Peattie', 'Helen Keller',
#        'Alexander Hamilton, John Jay, and James Madison',
#        'Arthur Ransome # in our series by Arthur Ransome Copyright laws are changing all over the wo',
#        'Chauncey M. Depew', 'Eleanor Farjeon',
#        'Benjamin Rumford Copyright laws are changing all over the world, be sure to',
#        'Giuseppe Salza', 'Dr. Martin Luther',
#        'Shakespeare, PG has multiple editions of William Shakespeare's Complete Works',
#        'James Lowell # in our series by James Russell Lowell Copyright laws are changing all over t',
#        'oject Gutenberg Etext of Autobiography of Andrew Dickson White # in our series Andrew Dickson White See also: Warfare of Science/Theology, An',
#        'St. John of Damascus', 'Lucan', 'Martha Summerhayes', 'James J. Davis',
#        'Phillis Wheatley', 'Hesther Lynch Piozzi, Edited by Henry Morley',
#        'W.J. Jackman and Thos. H. Russell', 'Ayn Rand',
#        'Johann Wolfgang Von Goethe',
#        'Modern American Authors # in our Lock and Key series edited by Julian Hawthorne Copyright laws are c',
#        'Robert Herrick', 'Walter Hawkins', 'Franz Josef Haydn',
#        'Mrs. Mary Rowlandson',
#        'Plaatje Copyright laws are changing all over the world, be sure to check the copyright',
#        'Cicero', 'Library of Congress', 'B.M. Sinclair, AKA B. M. Bower',
#        'English Authors: Orient, by Various', 'John Tyndall', 'John Ruskin.',
#        'Emile Zola', 'By Kate Douglas Wiggin', 'Joseph A. Munk',
#        'John N. Reynolds', 'Margaret Pollock Sherwood', 'Emma Wolf',
#        'Hugh Latimer, Edited by Henry Morley',
#        'Edgar B P Darlington Copyright laws', 'Andrew Dickson White',
#        'Ralph Parlette', 'Ed Krol',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyright laws ar',
#        'Oscar Wilde, Edited by Robert Ross', 'Mrs. Sutherland Orr',
#        'Saxo Grammaticus ("Saxo the Learned")', 'Ilya Tolstoy',
#        'Hjalmar Hjorth Boyesen', 'Daniel Defoe, Edited by Henry Morley',
#        'Avery Hopwood and Mary Roberts Rinehart', 'Helen Nicolay',
#        'A. A. Milne', 'John Filson', 'Electronic Frontier Foundation',
#        'Melvin L. Severy', 'Elizabeth Gaskell', 'H. Barber', 'Sylvester Mowry',
#        'Chretien DeTroyes',
#        'Edwin A. Abbott There are several editions of this ebook in the Project Gutenberg collection. Various',
#        'U.S. Census of Population and Housing and U.S. Dept. of Commerce, Econ',
#        'oject Gutenberg Etext of The Reign of King Edward the Third, attributed in part to William Shakespeare. PG has multiple editions of William S',
#        'Sir John Tenniel', 'John Dryden', 'Bruce Sterling', 'J. Munro',
#        'Clarence Edgar Johnson', 's, by Edgar Rice Burroughs',
#        'Frank T. Bullen', 'Frank Bird Linderman',
#        'Mary Esther Miller MacGregor, AKA Marion Keith', 'James Branch Cabell',
#        'Charles Dickens, Illustrated by F. H. Townsend',
#        'Jonathan Nield Copyright laws are changing all over the world, be sure to ch',
#        'Neltje Blanchan Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Don Marquis Copyright laws are changing all over the world',
#        'William S. Gilbert',
#        'Captain Marryat # in our series by Captain Marryat Copyright laws are changing all over the w',
#        'Gildas', 'Louise de la Ramee (AKA Ouida)',
#        'Geoffrey Chaucer Copyright laws are changing all over the world, be sure t',
#        'Kate Chopin',
#        'Joel Chandler Harris Copyright laws are changing all over the world. Be sure to check the copyrigh',
#        'Sydney Waterlow', 'Unknown Icelanders', 'Thomas Burke',
#        'Alexander H. Japp', 'Sun Tzu',
#        'Miss Mulock Pseudonym of Maria Dinah Craik',
#        'e Project Gutenberg EBook of The Holy Bible.', 'Fa-Hsien',
#        'John Fox Jr.',
#        'Long by Helen Beecher Long Copyright laws are changing all over the world, be sure',
#        'Rex Stout', 'David Herbert Lawrence', 'William Alexander Linn',
#        'Rene Doumic', 'Thomas Love Peacock',
#        'Library of Congress Copyright Office', 'John Philip Sousa',
#        'C. J. Cutcliffe Hyne', 'Myrtle Reed', 'Nettie Garmer Barker',
#        'Herbert N. Casson',
#        'Alexander Hamilton and John Jay and James Madison', 'Lew Wallace',
#        'Kakuzo Okakura', 'Joseph Rodman Drake', 'William Congreve',
#        'Hiram Corson', 'Edouard le Roy', 'Sarah Orne Jewett',
#        'Howard R. Garis',
#        'Gorky # in our series, by Maxim Gorky Copyright laws are changing all over the wor',
#        'Oliver Optic', 'E. R. Punshon', 'R. D. Blackmore',
#        'The Princess Der Ling', 'Gail Hamilton', 'Philip Melancthon',
#        'Hilda Conkling',
#        'The Project Gutenberg's Etext of Shakespeare's First Folio*** ********************The Tragedie of King Lear*******************',
#        'Project Gutenberg',
#        'e Project Gutenberg Etext "Divina Commedia di Dante: Inferno" In Italian with no accents Please see my notes about various versions b',
#        'e Project Gutenberg Etext of Organic Syntheses, Conant, Editor Caveat: Some numbers did not OCR correctly and may not have been corrected duri',
#        'Robert Burns', 'George W. Sands', 'Mark E. Laxer', 'Edwin A. Abbot',
#        'Frances E. W. Harper', 'E. V. Lucas', 'Gilbert K. Chesterton',
#        'A. Merritt', 'Scott Hemphill', 'Richard McGowan',
#        'Junction, by Charles Dickens', 'Upton Sinclair and Eugene Brieux',
#        'Victor Cherbuliez', 'Bayard Taylor', 'Donald Mackenzie Wallace',
#        'Richard de Bury', 'Ferdinand Ossendowski',
#        '(AKA Kate Douglas Riggs) Kate Douglas Wiggin', 'Mary Mapes Dodge',
#        'oject Gutenberg Etext of Cromwell attributed in part to Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyr',
#        'J. Fitzgerald Molloy', 'Jonathan Swift, Edited by Henry Morley',
#        'James Fenimore Cooper # in our series by James Fenimore Cooper Copyright laws are changing all ove',
#        'Henry Fielding', 'Francois Rabelais', 'John Quincy Adams',
#        'Oliver Wendell Holmes', 'W. H. Hudson',
#        'Edgar B. P. Darlington Copyrig',
#        'Samuel Adams (# in our series by Samuel Adams) Copyright law',
#        'James Thomson', 'Mine, by Margaret Mayo', 'Nicolo Machiavelli',
#        'Dorothy Kilner', 'Susanna Rowson', 'Thomas Hughes',
#        'William Shakespeare PG has multiple editions of William Shakespeare's Complete Work',
#        'Francis Bacon', 'Arthur Ransome', 'Harold MacGrath', 'Marvin Dana',
#        'Ross Kay', 'Mrs. W. G. Waters', 'George Gissing',
#        'Beatrix Potter Copyright laws are changing all over the worl',
#        'Stephen Levy', 'Christopher Marlowe', 'Arthur B. Reeve',
#        'Florence Converse', 'Bernardin de Saint Pierre', 'Theophile Gautier',
#        'Norman Coombs', 'Omar Khayyam', 'James M. Barrie', 'Brendan P. Kehoe',
#        'Sinclair Lewis', 'James Hogg', 'Andrew Lang.',
#        'Edward George Bulwer-Lytton',
#        'Wm J. Kountz, Jr. Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Edwin L. Arnold', 'Margaret E. Sangster',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyright la',
#        'Fyodor Dostoyevsky',
#        'oject Gutenberg Etext of . The Lamentable Tragedy of Locrine . Mucedorus attributed in part to William Shakespeare PG has multiple editio',
#        'M. G. Lewis', 'Friedrich Nietzsche', 'John Goodwin',
#        'George Borrow, Edited by T. H. Darlow',
#        'Joel Benton. Copyright laws are changing al',
#        'James F. Cooper # in our series by James Fenimore Cooper Copyright la',
#        'e Project Gutenberg Etext of Stories from Everybody's Magazine From the issues of Everybody's Magazine Copyright laws are changing all o',
#        'Gary Mann', 'John Lawson', 'William J. Claxton',
#        'on And Egypt, by Leonard W. King',
#        'George Wharton James Copyright laws are changing all over the world, b',
#        'E THREE MUSKETEERS', 'William Osler', 'Joseph E. Badger, Jr.',
#        'Alan Seeger', 'Amy Steedman',
#        'Robert Louis Stevenson, Illustrated by Walter Crane', 'Plutarch',
#        'Kipling # in our series by Rudyard Kipling Copyright laws are changing all over the w',
#        'Mary Austin', 'Geoffrey Chaucer', 'Alfred Lord Tennyson',
#        'Charles and Mary Lamb', 'Helen Bannerman',
#        'Miller Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Jane Addams Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Carl von Clausewitz', 'Henry Kendall',
#        'Sinclair # in our series by Upton Sinclair Copyright laws are changing all over the wor',
#        'L. Frank Baum.',
#        'George Iles Copyright laws are changing all over the world, be sure to',
#        'e Project Gutenberg Etext of An Anthology of Australian Verse Copyright laws are changing all over the world, be sure to check the copyright',
#        'L. Adams Beck', 'Gilbert Keith Chesterton', 'Arthur Machen',
#        'Charlotte M. Braeme', 'Franklin Delano Roosevelt',
#        'Vicente Blasco Ibanez', 'John Dewey', 'Jean-Baptiste Poquelin Moliere',
#        'Gideon Wurdz', 'William Gilmore Simms',
#        '"Elizabeth", AKA Marie Annette Beauchamp', 'Hans Christian Andersen',
#        'Thomas Nelson Page', 'Herman Melville', 'Edmond Rostand',
#        'Lazarillo of Tormes',
#        'O. Henry, Illustrated by H. C. Greening and May Wilson Preston',
#        'Thorstein Veblen', 'Rutherford Platt', 'Christopher Evans',
#        'e Project Gutenberg Etext of The Narrative of Sojourner Truth',
#        'T. S. Eliot', 'Edward Bellamy', 'Sir Walter Raleigh',
#        'Percival Lowell', 'Adelaide L. Fries', 'Benjamin Franklin',
#        'Eugene Field', 'Joseph A. Altsheler', 'Julian Hawthorne',
#        'August Niemann', 'Margaret Mayo', 'Adelaide Anne Procter, et al',
#        'Elizabeth Drew Stoddard', 'Nennius', 'Lucretius', 'Eliza Burt Gamble',
#        'Niccolo Machiavelli', 'Anna Sewell',
#        'J. Henri Fabre, Translated by Alexander Teixeira de Mattos',
#        'Dumont Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Mariano Azuela', 'European Union', 'Sextus Propertius',
#        'Proudhon # in our series by Joseph-Pierre Proudhon Copyright laws are changing all ove',
#        'White Sands Missile Range Public Affairs Office',
#        'Charles Oliver Copyright laws are changing all over the world, be sure to check the copyright l',
#        'Jerome Klapka, AKA Jerome K. Jerome',
#        'oject Gutenberg's Etext of The Life of General Francis Marion',
#        'Richard Brinsley Sheridan', 'Rev. James MacCaffrey Copyright laws',
#        'A. B. Paterson', 'Thomas Holmes', 'Upton Sinclair', 'Oliver Goldsmith',
#        'Alfred, Lord Tennyson', 'George Smith',
#        'Robert Louis Stevenson, et al', 'William J. Long',
#        'Robert Louis Stevenson and Lloyde Osbourne', 'Feodor Dostoevsky',
#        'R. S. Ball',
#        'oject Gutenberg Etext: A Journey in Other Worlds, J. J. Astor Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Browning, Elizabeth Barrett',
#        'George MacDonald (# in our series by George MacDonald) Copyright laws are changing all over t',
#        'E. S. Brooks', 'J. Frank Dobie', 'S. A. Reilly', 'Louis de Rougemont',
#        'J. E. Hutton', 'Arthur Hugh Clough',
#        'Step, by The American Tract Society', 'Arnold Bennett', 'Lucy Larcom',
#        'Henry W. Longfellow', 'B.M. Bower', 'Pierre Loti', 'Noah Brooks',
#        'Henry David Thoreau', 'Nathaniel Wright Stephenson', 'Padraic Colum',
#        'Eden Phillpotts', 'John Breckinridge Ellis', 'John Charles McNeill',
#        '(AKA David Grayson) Ray Stannard Baker', 'Johann Wolfgang von Goethe',
#        'Mary Wollstonecraft', 'B.M. Sinclair, AKA B.M. Bower',
#        'Torquato Tasso',
#        'John M. Coulter Copyright laws are changing all over the world, be sure to c',
#        'Smiles # in our series by Samuel Smiles Copyright laws are changing all over the wo',
#        'Henry Benjamin Wheatley', 'Sarah Fielding', 'Boz, by Charles Dickens',
#        'An Anonymous Young Girl', 'Michael Hart',
#        'oject Gutenberg Etext of The Dore' Lectures on Mental Science Copyright laws are changing all over the world, be sure to check the copyright',
#        'M. Y. Lermontov', 'Joseph McCabe',
#        'Shakespeare PG has multiple editions of William Shakespeare's Complete Works Copyright'],
#       dtype='object')

# %%
#make corrections
corrections = ['Hesther Lynch Piozzi','Beatrix Potter','Susan Fenimore Cooper','Baker','Hale','Cunninghame Graham','Charles Oliver', 'William Makepeace Thackeray', 
               "Shakespeare", 'James Russell Lowell', 'Henry Wadsworth Longfellow', 'Andrew Dickson White', 'Ayn Rand', 'Fannie Isabelle Sherrick', 'John Lord', 'James Lane Allen',
               'Jack London', 'William Wells Brown', 'Thomas A Kempis', "Alexander Pope", 'Louis Ginzberg', 'Jerome K. Jerome', 'Maurice Maeterlinck', 'George Wharton James', 
                'Rudyard Kipling', 'Jerome Lobo', 'James F. Cooper', 'Charles Dickens', 'Upton Sinclair', 'Johanna Spyri', 'William and Ellen Craft', 
               'James Whitcomb Riley', 'Helen Beecher Long', 'Joseph-Pierre Proudhon', 'Arthur Brisbane', 'Julian Hawthorne', 'R. M. Ballantyne']
for corr in corrections:
    df.loc[df.author.str.contains(corr), 'author'] = corr

# %%
#unknowns, aliases, etc.
unknowns = [' and ', 'various', 'anonymous', 'unknown', 'enty years after', 'gutenberg', '\(', 'edited', 'illustrated', "copyright"]
various = df.loc[df.author.str.lower().str.contains('|'.join(unknowns))]

df.loc[df.author.str.lower().str.contains('|'.join(unknowns))] = float("NaN")
df.dropna(inplace=True)

#aliases that are labeled with AKA. 
df.loc[df.author.str.contains('AKA')] = float("NaN")
df.dropna(inplace=True)

# %%
#Reduce author counts to fifty. 
author_counts = df.author.value_counts()[0:15]
keep = author_counts[author_counts.values > 3]

#reassign the dataframe to these values. 
df = df[df.author.isin(author_counts.index)].copy()

# %%
#Remove all the works after the first three, because we only want three of them. 
for a in keep.index:
    remove_index = df[df.author.isin([a])][3:].index
    df.drop(remove_index, inplace=True)

# %%
#Number of documents.
df.author.value_counts().sum()
# Out:
# 45

# %% [markdown]
# The NLP generated some kind of an error message when the text exceeded a number of characters.
# The following steps were taken:
# > Increased page file size.
#
# > Set PC properties to maximize peformance.
#
# > Reduced the variable t to translate at that amount.
#
# *note: originally I had run nlp against all 2,000 records to set them out as documents. It took over four hours to process all 2k records, the large dataset caused frequent lagging and I would often have to reboot my computer; slowing down the project.*

# %%
#Now is the time. Turn these text fields into documents.
nlp = en_core_web_sm.load()
doc = []
author = []
i = 0
df['doc'] = ""
df['no_stop'] = ""
# All the processing work takes place below, so it may take a while.
for index, t in df.iterrows():
    print(f'{dt.datetime.now().strftime("%d/%m/%Y %H:%M:%S")} working on doc {i}')
    #try to process the text file into a document. Skip it if it can't. As many as possible.
    try:
        #500000 characters seems long enough for this exercise. I just want to identify the author - which is a text field labled "Author:" or whoever is after the "by" statement. 
        t['doc'] = nlp(t.text[0:500000])
        t['no_stop'] =  [token for token in t.doc if not token.is_stop]
        i += 1
    except:
        i += 1
        print("encountered an exception, skipping to next document.")
# Out:
# 27/12/2020 17:57:31 working on doc 0
# 27/12/2020 17:57:39 working on doc 1
# 27/12/2020 17:57:48 working on doc 2
# 27/12/2020 17:57:58 working on doc 3
# 27/12/2020 17:58:10 working on doc 4
# 27/12/2020 17:58:19 working on doc 5
# 27/12/2020 17:58:33 working on doc 6
# 27/12/2020 17:58:37 working on doc 7
# 27/12/2020 17:58:49 working on doc 8
# 27/12/2020 17:59:02 working on doc 9
# 27/12/2020 17:59:12 working on doc 10
# 27/12/2020 17:59:25 working on doc 11
# 27/12/2020 17:59:37 working on doc 12
# 27/12/2020 17:59:47 working on doc 13
# 27/12/2020 17:59:52 working on doc 14
# 27/12/2020 17:59:58 working on doc 15
# 27/12/2020 18:00:01 working on doc 16
# 27/12/2020 18:00:15 working on doc 17
# 27/12/2020 18:00:26 working on doc 18
# 27/12/2020 18:00:32 working on doc 19
# 27/12/2020 18:00:41 working on doc 20
# 27/12/2020 18:00:45 working on doc 21
# 27/12/2020 18:00:48 working on doc 22
# 27/12/2020 18:00:51 working on doc 23
# 27/12/2020 18:00:58 working on doc 24
# 27/12/2020 18:01:04 working on doc 25
# 27/12/2020 18:01:13 working on doc 26
# 27/12/2020 18:01:25 working on doc 27
# 27/12/2020 18:01:38 working on doc 28
# 27/12/2020 18:01:50 working on doc 29
# 27/12/2020 18:01:56 working on doc 30
# 27/12/2020 18:01:57 working on doc 31
# 27/12/2020 18:02:00 working on doc 32
# 27/12/2020 18:02:02 working on doc 33
# 27/12/2020 18:02:15 working on doc 34
# 27/12/2020 18:02:27 working on doc 35
# 27/12/2020 18:02:41 working on doc 36
# 27/12/2020 18:02:46 working on doc 37
# 27/12/2020 18:02:47 working on doc 38
# 27/12/2020 18:02:49 working on doc 39
# 27/12/2020 18:03:01 working on doc 40
# 27/12/2020 18:03:13 working on doc 41
# 27/12/2020 18:03:15 working on doc 42
# 27/12/2020 18:03:28 working on doc 43
# 27/12/2020 18:03:31 working on doc 44

# %%
dist_plot = df[['author', 'doc']].iloc[0]
length = [len(w) for w in dist_plot.doc]
fdist = nltk.FreqDist(length)
fdist.plot(title=dist_plot.author)
# Out:
# <AxesSubplot:title={'center':'L. Frank Baum'}, xlabel='Samples', ylabel='Counts'>

# %%
# Instantiate your list of the most common words
word_freq = word_frequencies(dist_plot.doc).most_common(10)
print(f'Word Frequencies count for {dist_plot.author} is:\n {word_freq}')
# Out:
# Word Frequencies count for L. Frank Baum is:
#  [('the', 3227), ('\r\n', 2577), ('\r\n\r\n', 1454), ('and', 1385), ('to', 1278), ('of', 1087), ('a', 997), ('I', 662), ('in', 573), ('you', 457)]

# %%
#Pickle the author and doc in case I have to reboot. 
timer('pickling dataframes.')

with open(filename, 'wb') as f:
    pickle.dump(df[['author', 'doc']], f)

timer('done pickling dataframes')
# Out:
# 27/12/2020 18:03:38: pickling dataframes.
# 27/12/2020 18:03:59: done pickling dataframes

# %% [markdown]
# # Feature Engineering
#
# Here is where we engineer features for modeling.

# %%
#This is a convenient function for creating a new dataframe, should I run into an error. 
#This function returns a dataframe with sentences from the pickle file that was saved to the filename location.

def get_docs(filename, df=None):
    if df is None:
        with open(filename, 'rb') as f:
            df = pickle.load(f)
        list_sentences = []

    for index, row in df.iterrows():
        list_sentences += ([[sent, row.author] for sent in row.doc.sents])

    # Combine the sentences from the two novels into one DataFrame
    sentences = pd.DataFrame(list_sentences, columns = ["sentences", "author"])
    
    # Get rid of stop words and punctuation and lemmatize the tokens
    for i, sentence in enumerate(sentences["sentences"]):
        sentences.loc[i, "sentences"] = [text_cleaner(token.lemma_) for token in sentence if not token.is_punct and not token.is_stop]
    return sentences

# %%
sentences = get_docs(filename, df)
sentences
# Out:
#                                                 sentences         author
# 0       [Project, Gutenberg, EBook, Marvellous, Land, ...  L. Frank Baum
# 1         [eBook, use, cost, , restriction, whatsoever, ]  L. Frank Baum
# 2       [copy, away, , use, term, Project, Gutenberg, ...  L. Frank Baum
# 3       [include, , eBook, online, www.gutenberg.net, ...  L. Frank Baum
# 4       [Marvellous, Land, Oz, , author, L., Frank, Ba...  L. Frank Baum
# ...                                                   ...            ...
# 154490  [thirty, year, produce, distribute, Project, ,...     Bret Harte
# 154491  [Project, Gutenberg, tm, eBooks, create, print...     Bret Harte
# 154492  [necessarily, , eBooks, compliance, particular...     Bret Harte
# 154493  [people, start, web, site, main, pg, search, f...     Bret Harte
# 154494  [web, site, include, information, Project, Gut...     Bret Harte
#
# [154495 rows x 2 columns]

# %% [markdown]
# # Model Preparation

# %%
#Some constant variables for parameter settings. 
#cross validation, constant parameter
cv = 5

#multiclass
mc = ['auto', 'ovr', 'multinomial']
#solver
sv = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
#penalty
py = ['l1', 'l2', 'elasticnet', 'none']
#criterion
cn = ['gini', 'entropy']
#max_features
mf = ['auto', 'sqrt', 'log2']
#splitter
sr = ['best', 'random']
#max_depth
#md = [5, 7, 15, 29] 
md = [15, 50] 
#n_estimators
ne = [n+50 for n in range(50, 500, 50)]  
#max_iter
mi = [n+50 for n in range(450, 1500, 50)]

# %%
#logistic regression
lrp = {   # "lr__multi_class": mc, 
          # "lr__solver": sv,
          # 'lr__penalty' : py,
           "lr__max_iter": mi
      }
#decision tree
dtp = {
           #'dt__criterion': cn,
           'dt__max_features': mf,
           #'dt__splitter':sr, 
           'dt__max_depth': md     
}
#K Nearest Neighbors
knnp = {
           'knn__n_neighbors': [3, 39, 12],
           #'knn__weights': ['uniform', 'distance'],
           #'knn__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'], 
           'knn__leaf_size': [30, 12, 9],  
           #'knn__metric': ['mahalanobis','euclidean', 'manhattan', 'chebyshev', 'minkowski', 'seuclidean'],  
}
#Support Vector Classifier
svp = {
          'sv__kernel': ['linear', 'rbf'],
          'sv__break_ties': [True, False],
}
#Random Forest Classifier 
rfp = {
           #'rf__criterion': cn,
           #'rf__max_features': mf,
           #'rf__oob_score':[True, False], 
           'rf__max_depth': md,
           'rf__n_estimators': ne,     
}
#gradient boost 
gbp = {    #'gb__criterion': ['friedman_mse', 'mse', 'mae'],
           #'gb__max_features': mf,
           'gb__max_depth': md, 
           'gb__n_estimators': ne
          }
vr = {
      'vectorizer__max_df': (0.5, 0.75, 1.0), 
      'vectorizer__max_features': (None, 5000, 10000, 50000)
     }

# %% [markdown]
# # Bag of Words

# %% [markdown]
# For bag of words, I have to troubleshoot a memory error.
#
# `MemoryError: Unable to allocate 27.0 TiB for an array with shape (6566859, 565300) and data type int64`
#
# Step One: Reduce the size by changing the data type.
#
# > Another error arises when I attempt to mask the shape to an int8.
#
# >```
# import numpy as np
# mask = np.zeros(X.shape,dtype='uint8')
# >```
#
# >`MemoryError: Unable to allocate 3.38 TiB for an array with shape (6566859, 565300) and data type uint8`
#
#
# Step Two: Reduce content by reducing authors.
# > Project requirements said ten authors and thousands of texts, with at least seven novels.
#
# > I returned to the data cleaning process to eliminate various/anonymous/unknown authors.
#
# > I still get an error.
#
# > `MemoryError: Unable to allocate 16.1 TiB for an array with shape (5928859, 373831) and data type int64`
#
# Step Three: Reduce content again by reducing authors in a way such that the dataset is more balanced.
# >I returned to the data cleaning process to reduce the number of works of those largest authors to three or four.
#
# >Received a similar memory error.
#
# Step Four: Skip the dataframe, train the model.
#
# > Received a similar memory error and the entire system locked up.
#
# Step Five: Reduce the number of authors.
# > ```Unable to allocate 7.31 GiB for an array with shape (2952352, 665) and data type int32```
#
# > Return to data cleaning and choose the top 100 authors. Decrease steadily until the program runs.

# %%
y = sentences['author']
X = sentences['sentences']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
X_train = X_train.astype(str)
X_test = X_test.astype(str)

# %%
model_data('Naive Bayes', '', ('nb', ComplementNB()))
# Out:
# 28/12/2020 14:17:26, started Naive Bayes grid search
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  1.7min finished
# 28/12/2020 14:19:08, Naive Bayes grid search complete
#                        precision    recall  f1-score   support
#
#    Arthur Conan Doyle       0.37      0.49      0.42      2958
#            Bret Harte       0.65      0.47      0.54      1866
#       Charles Dickens       0.60      0.56      0.58      2841
#  Edgar Rice Burroughs       0.56      0.68      0.61      2185
#           Henry James       0.55      0.57      0.56      3389
#      Honore de Balzac       0.44      0.32      0.37       918
#           Jack London       0.56      0.49      0.52      1925
#      Jerome K. Jerome       0.56      0.31      0.40      1457
#         Joseph Conrad       0.56      0.25      0.34      1600
#         L. Frank Baum       0.68      0.65      0.66      1770
#                 Plato       0.47      0.73      0.57      1696
# Richard Harding Davis       0.44      0.31      0.37       890
#           Shakespeare       0.58      0.53      0.55      1505
#        Thomas Carlyle       0.55      0.67      0.60      2417
#        Wilkie Collins       0.54      0.57      0.55      3482
#
#              accuracy                           0.53     30899
#             macro avg       0.54      0.51      0.51     30899
#          weighted avg       0.54      0.53      0.53     30899

# %%
model_data("decision tree", dtp, ('dt', DecisionTreeClassifier()), n_jobs=-1)
# Out:
# 28/12/2020 16:00:31, started decision tree grid search
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  2.4min finished
# 28/12/2020 16:02:59, decision tree grid search complete
#                        precision    recall  f1-score   support
#
#    Arthur Conan Doyle       0.97      0.06      0.12      2958
#            Bret Harte       0.98      0.02      0.05      1866
#       Charles Dickens       0.59      0.19      0.28      2841
#  Edgar Rice Burroughs       0.96      0.14      0.24      2185
#           Henry James       0.82      0.13      0.22      3389
#      Honore de Balzac       0.71      0.07      0.13       918
#           Jack London       0.96      0.04      0.07      1925
#      Jerome K. Jerome       0.48      0.03      0.05      1457
#         Joseph Conrad       0.47      0.02      0.03      1600
#         L. Frank Baum       0.93      0.19      0.32      1770
#                 Plato       0.26      0.14      0.19      1696
# Richard Harding Davis       0.78      0.04      0.08       890
#           Shakespeare       0.16      0.05      0.08      1505
#        Thomas Carlyle       0.31      0.07      0.12      2417
#        Wilkie Collins       0.12      0.91      0.21      3482
#
#              accuracy                           0.19     30899
#             macro avg       0.63      0.14      0.15     30899
#          weighted avg       0.63      0.19      0.16     30899

# %%
model_data('Logistic Regression', lrp,  ('lr', LogisticRegression()), n_jobs=-1)

# %%
model_data('Gradient Boosting', gbp, ('gb', GradientBoostingClassifier()), n_jobs=-1)

# %%
model_data('K Nearest Neighbors', knnp, ('knn', KNeighborsClassifier()), n_jobs=-1)

# %%
model_data('Support Vector Model', svp, ('sv', SVC(), n_jobs=-1)

# %%
model_data("Random Forest", rfp, ('rf', RandomForestClassifier(random_state=1)))
