# %% [markdown]
# # Author Classification Project
#
# *a thinkful project by Kalika Kay Curry*
#
# Build a project to classify text-author.
#
# Collect thousand texts from Gutenberg project (and 7 novels) for at least 10 authors.

# %%
from urllib import request
import pandas as pd
import en_core_web_sm
import nltk
from nltk.corpus import gutenberg
import re
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
import datetime as dt
import seaborn as sns
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import plotly.express as px
import pickle
import joblib
import numpy as np

#Where the pickle file is stored. 
filename = "..\d_store\data.pkl"

# %%
# Utility function for standard text cleaning
def text_cleaner(text):
    # Visual inspection identifies a form of punctuation that spaCy doesn't
    # recognize: the double dash --. Better get rid of it now!
    text = ' '.join(text.split())
    text = re.sub(r"\r?\n|\r", " ", text)
    text = re.sub(r'--',' ',text)
    text = re.sub(r"(\b|\s+\-?|^\-?)(\d+|\d*\.\d+)\b", " ", text)
    text = re.sub("[\[].*?[\]]", "", text)
    return text

# %%
def length_frequencies(text):
    length = [len(w) for w in text]
    fdist = nltk.FreqDist(length)
    return fdist

# %%
# Utility function to calculate how frequently words appear in the text
def word_frequencies(text):
    
    # Build a list of words
    # Strip out punctuation
    words = []
    for token in text:
        if not token.is_punct:
            words.append(token.text)
            
    # Build and return a `Counter` object containing word counts
    return Counter(words)

# %%
def timer(text):
    print(f'{dt.datetime.now().strftime("%d/%m/%Y %H:%M:%S")}: {text}')

# %%
def listtostrings(s):
    return ' '.join([str(elem) for elem in s])

# %%
#Thousands of Gutenberg texts.
print(f'{dt.datetime.now().strftime("%d/%m/%Y %H:%M:%S")}, started')
text2000 = []
i = 9
count = 0
while count != 2000:    
    try:
        url = f'http://www.gutenberg.org/files/{i}/{i}.txt'
        response = request.urlopen(url)
        raw = response.read().decode('utf8')
        text2000.append(raw )
        count += 1
        i += 1
    except:
        i += 1
print(f'{dt.datetime.now().strftime("%d/%m/%Y %H:%M:%S")}, ended')
# Out:
# 27/12/2020 14:24:57, started
# 27/12/2020 14:47:33, ended

# %% [markdown]
# # Authors
#
# The texts from the Gutenberg library does not provide authors in a seperate field. Even the html files don't contain a seperate author field for identifying, easily, who the work is by; so I can't really run a classifier on this yet.
#
# At the same time, I'm curious who these 2,000 works are by - how many of each author do I have? So a little bit of data exploration and preprocessing to get the authors.

# %% [markdown]
# From working with gutenberg data in previous examples, I know that most authors appear within the first 150 characters of the text. Usually it's less than 150 characters, somewhere in the 75 character range. I want the first 150 characters because of this.

# %%
#Authors names usually appear within the first 150 characters. 
authors = []
for text in text2000:
    authors.append(text_cleaner(text[0:150]))
print(authors[10:15])
# Out:
# ["The Project Gutenberg EBook of Roget's Thesaurus, by Peter Mark Roget This eBook is for the use of anyone anywhere at no cost and with almost no r", 'The Project Gutenberg EBook of The Narrative of the Life of Frederick Douglass, by Frederick Douglass This eBook is for the use of anyone anywhe', 'The Project Gutenberg EBook of O Pioneers!, by Willa Cather This eBook is for the use of anyone anywhere at no cost and with almost no restriction', 'The Project Gutenberg EBook of The CIA World Factbook, by United States. Central Intelligence Agency. This eBook is for the use of anyone a', 'The Project Gutenberg EBook of Paradise Lost, by John Milton ******************************************************************* THIS EBOOK WAS']

# %%
#Authors will appears after the word "by"
tokens = nltk.word_tokenize(listtostrings(authors))
authortext = nltk.Text(tokens)

#abandoing this method for - reasons.
first = nltk.text.ConcordanceIndex(authortext).offsets('by') 
example = []
for x in first:
    example.append(authortext[x+1])
print(example[0:15])
# Out:
# ['Abraham', 'Charles', 'Lewis', 'United', 'James', 'Anonymous', 'Alexander', 'Henry', 'John', 'Peter', 'Frederick', 'Willa', 'United', 'John', 'Thomas']

# %%
#Looking at how often the words Gutenberg and by appear in the text.
authortext.dispersion_plot([' by ', 'Gutenberg', 'Anonymous', 'Various', 'This', 'Author'])

# %%
authortext.concordance('Gutenberg')
# Out:
# Displaying 25 of 2007 matches:
# The Project Gutenberg EBook of Lincoln 's First Inaugura
#  of anyone anywhere a ﻿The Project Gutenberg EBook of The King James Bible * *
#  * EBOOK ( # ) WAS ONE The Project Gutenberg EBook of Through the Looking-Glass
# eBook is for the use o The Project Gutenberg EBook of The Hunting of the Snark
# o cost and with almost The Project Gutenberg EBook of The CIA World Factbook ,
# r the use of anyone an The Project Gutenberg EBook of Peter Pan , by James M. B
# h almost no restrictio The Project Gutenberg EBook of The Book Of Mormon , by A
# with almost no restric The Project Gutenberg EBook of The Federalist Papers , b
# r the use of anyone an The Project Gutenberg EBook of The Song Of Hiawatha , by
# no cost and with almos The Project Gutenberg EBook of Paradise Lost , by John M
# h almost no restrictio The Project Gutenberg EBook of Roget 's Thesaurus , by P
# t and with almost no r The Project Gutenberg EBook of The Narrative of the Life
# e use of anyone anywhe The Project Gutenberg EBook of O Pioneers ! , by Willa C
#  almost no restriction The Project Gutenberg EBook of The CIA World Factbook ,
# or the use of anyone a The Project Gutenberg EBook of Paradise Lost , by John M
# * * * * THIS EBOOK WAS The Project Gutenberg EBook of Far from the Madding Crow
#  * * * * * * * * * THI The Project Gutenberg EBook of Aesop 's Fables , by Aeso
# ost no restrictions wh The Project Gutenberg EBook of Census of Population and
# k is for the use of anyone Project Gutenberg 's The Bible , King James Version
# ost and with almost no The Project Gutenberg EBook of The Oedipus Trilogy , by
#  with almost no restri The Project Gutenberg EBook of Herland , by Charlotte Pe
# no cost and with almos The Project Gutenberg EBook of The Scarlet Letter , by N
# at no cost and with almost Project Gutenberg 's Zen and the Art of the Internet
# cost and with almost n The Project Gutenberg EBook of The War of the Worlds , b
#  and with almost no re The Project Gutenberg EBook of Census of Population and

# %%
#This is the best that I can do. 
name = []
for x in authors:
    first = x.find('by') + len('by ')
    last = x.find('This') 
    if last == -1:
        last = x.find('*')
    name.append(text_cleaner(x[first:last].strip("*")))
print(name[0:25])
# Out:
# ['Abraham Lincoln', 'he Project Gutenberg EBook of The King James Bible', 'Charles Dodgson AKA Lewis Carroll', 'Lewis Carroll', 'United States. Central Intelligence Agency', 'James M. Barrie', 'Anonymous', 'Alexander Hamilton and John Jay and James Madison', 'Henry W. Longfellow', 'John Milton', 'Peter Mark Roget', 'Frederick Douglass', 'Willa Cather', 'United States. Central Intelligence Agency.', 'John Milton', 'Thomas Hardy', 'Aesop', 'United States Bureau of the Census', 'Various', 'Sophocles', 'Charlotte Perkins Stetson Gilman', 'Nathaniel Hawthorne', 'Brendan P. Kehoe', 'H. G. Wells', 'United States Bureau of the Census']

# %%
d = { 'author': name, 'text': text2000}
df = pd.DataFrame(d)

# %%
#Clean the text, like for authors.
df['text'].apply(lambda x: text_cleaner(x))
df.head()
# Out:
#                                               author  \
# 0                                    Abraham Lincoln
# 1  he Project Gutenberg EBook of The King James B...
# 2                  Charles Dodgson AKA Lewis Carroll
# 3                                      Lewis Carroll
# 4         United States. Central Intelligence Agency
#
#                                                 text
# 0  The Project Gutenberg EBook of Lincoln's First...
# 1  ﻿The Project Gutenberg EBook of The King James...
# 2  The Project Gutenberg EBook of Through the Loo...
# 3  The Project Gutenberg EBook of The Hunting of ...
# 4  The Project Gutenberg EBook of The 1990 CIA Wo...

# %%
df[df.author == '']
# Out:
#      author                                               text
# 329          ***The Project Gutenberg Etext of The Hymns of...
# 352          **The Project Gutenberg Etext of The Crowd, by...
# 355          **The Project Gutenberg Etext of The Psycholog...
# 356          ****The Project Gutenberg Etext of Pathology o...
# 361          ***The Project Gutenberg Etext of "The Breitma...
# ...     ...                                                ...
# 1835         \r\n\r\n\r\n\r\n******************************...
# 1896         **This is a COPYRIGHTED Project Gutenberg Etex...
# 1985         ***Project Gutenberg Etext: The Circus Boys Ac...
# 1986         ***Project Gutenberg Etext: The Circus Boys In...
# 1995         **The Project Gutenberg Etext of Moby Dick, by...
#
# [136 rows x 2 columns]

# %%
#Drop authors that haven't been parsed. 
df.author.replace('', float("NaN"), True)
df.dropna(inplace=True)

# %%
#Update some names. 
pd.options.display.max_seq_items = 1000
df.author.value_counts().index
# Out:
# Index(['Honore de Balzac', 'Shakespeare', 'Thomas Carlyle',
#        'Richard Harding Davis', 'Charles Dickens', 'Jack London', 'Plato',
#        'Joseph Conrad', 'Jerome K. Jerome', 'Henry James', 'Various',
#        'Arthur Conan Doyle', 'Anonymous', 'Edgar Rice Burroughs', 'Bret Harte',
#        'Wilkie Collins', 'L. Frank Baum', 'Robert Louis Stevenson',
#        'Victor Appleton', 'Xenophon', 'Rudyard Kipling',
#        'Mary Roberts Rinehart', 'Unknown', 'H. G. Wells',
#        'Nathaniel Hawthorne', 'Kate Douglas Wiggin', 'Jules Verne',
#        'Zane Grey', 'Booth Tarkington', 'Edith Wharton',
#        'William Makepeace Thackeray', 'Owen Wister', 'Frances Hodgson Burnett',
#        'E. Phillips Oppenheim', 'Max Beerbohm', 'Andrew Lang',
#        'Robert Nemiroff and Jerry Bonnell', 'Sir Walter Scott',
#        'Alice Meynell', 'B. M. Bower', 'Thomas Babington Macaulay',
#        'Thomas Bailey Aldrich', 'George Bernard Shaw', 'O. Henry',
#        'George MacDonald', 'Thomas Hardy', 'Charles Darwin',
#        'Anthony Trollope', 'Lucy Maud Montgomery', 'David Graham Phillips',
#        'Washington Irving', 'Sax Rohmer', 'Jane Austen', 'Virgil',
#        'John Milton', 'Leo Tolstoy', 'William Dean Howells', 'United States',
#        'Edna Ferber', 'United States. Central Intelligence Agency.',
#        'E. Nesbit', 'Oscar Wilde', 'Edward Gibbon', 'Benedict de Spinoza',
#        'Charles Kingsley', 'G. K. Chesterton', 'H. Rider Haggard',
#        'Willa Cather', 'Joseph C. Lincoln', 'Sara Teasdale', 'George Borrow',
#        'Stewart Edward White', 'J. M. Synge', 'Dante Alighieri',
#        'Herbert George Wells', 'G.K. Chesterton', 'Emile Gaboriau',
#        'Robert W. Service', 'Henry van Dyke', 'E. W. Hornung', 'Henry Lawson',
#        'Stanley Weyman', 'William MacLeod Raine', 'James Fenimore Cooper',
#        'Susan Fenimore Cooper', 'Anton Checkov', 'Edgar Allan Poe',
#        'Olive Schreiner', 'Benedict of Spinoza', 'Gene Stratton-Porter',
#        'Howard Pyle', 'Henry Smith Williams', 'Julian Hawthorne',
#        'Frank Norris', 'Eleanor H. Porter', 'George Eliot',
#        'Henry Wadsworth Longfellow', ', Charles A. Eastman', 'Daniel Defoe',
#        'Horatio Alger, Jr.', 'Horatio Alger',
#        'Robert Louis Stevenson, Edited by Sidney Colvin', 'Martin Luther',
#        'William Morris', 'Herbert A. Giles', 'Ernest Bramah',
#        'Kenneth Grahame', 'Joseph Sheridan Le Fanu', 'Anton Chekhov',
#        'Alphonse Daudet', 'Baker', 'Don Marquis', 'Albert Payson Terhune',
#        'Frederick Douglass', 'Thornton W. Burgess', 'Irvin S. Cobb',
#        'Amy Lowell', 'Edwin Arlington Robinson', 'J. M. Barrie', 'Edna Lyall',
#        'Andrew Barton 'Banjo' Paterson', 'Rebecca Harding Davis',
#        'Samuel Smiles', 'Samuel Butler', 'Stephen Crane', 'Henrik Ibsen',
#        'Gaston Leroux', 'William Wells Brown', 'Anna Katharine Green',
#        'Vachel Lindsay', 'Upton Sinclair', 'Charles Mackay', 'Ambrose Bierce',
#        'Gene Stratton Porter', 'John Buchan', 'Andrew Dickson White',
#        'Gustave Flaubert', 'P. G. Wodehouse', 'Charles Reade',
#        'Alexander Whyte', 'Rafael Sabatini', 'Edward Bulwer Lytton',
#        'United States Central Intelligence Agency', 'James Whitcomb Riley',
#        'Elia W. Peattie', 'Mary E. Wilkins Freeman', 'Theodore Dreiser',
#        'or about Honore de Balzac Copyright laws are changing al',
#        'Frank Stockton', 'Beatrix Potter', 'Frank R. Stockton', 'Jean Webster',
#        'Anthony Hope', 'Ayn Rand', 'An Imitator of Plato',
#        'Ernest Thompson Seton', 'Ellis Parker Butler', 'W. Somerset Maugham',
#        'Mark Twain', 'Edna St. Vincent Millay', 'Anatole France',
#        'Tobias Smollett', 'Frank L. Packard', 'John Galt', 'Laura Lee Hope',
#        'Oliver Wendell Holmes, Jr.', 'Sara Cone Bryant', 'Edgar A. Guest',
#        'Isaac Taylor Headland', 'Augusta Groner',
#        'Mark Twain (Samuel Clemens)', 'Thomas Wentworth Higginson',
#        'Grace Isabel Colbron and Augusta Groner', 'William Blake', 'John Lord',
#        'Sophocles', 'Maria Edgeworth', 'Jean Armour Polly', 'Ulysses S. Grant',
#        'Louis Ginzberg', 'Louisa May Alcott', 'John Fiske',
#        'Alexis de Toqueville', 'Saki', 'United States Bureau of the Census',
#        'John Greenleaf Whittier', 'Charles Brockden Brown',
#        'Richard Jefferies', 'Bram Stoker', 'Andrew Steinmetz',
#        'George Meredith', 'Horatio Alger Jr.', 'Amelia E. Barr',
#        'Walter Pater', 'Algernon Charles Swinburne', 'Thomas Henry Huxley',
#        'Francis Thompson', 'Robert Louis Stevenson and Lloyd Osbourne',
#        'Japan', 'James Russell Lowell', 'Aristotle', 'Virginia Woolf',
#        'Maxim Gorky', 'Ludwig van Beethoven', 'Harold Frederic',
#        'Lytton Strachey', 'Lewis Carroll', 'Donald Ogden Stewart', 'Hale',
#        'Christopher Morley', 'Herodotus', 'John Farrar',
#        'Ellen Glasgow Copyright laws are changing all over the worl',
#        'Henry Adams', 'John Fox', 'B. Perez Galdos', 'Greg Fee', 'John Keats',
#        'Frances Bacon', 'H. Stanley Redgrove', 'John Webster',
#        'William Dobein James',
#        'United States National Aeronautics and Space Administration',
#        'Maurice Maeterlinck', 'Herbert Darling Foster', 'Hesther Lynch Piozzi',
#        'H. B. Irving', 'Thomas De Quincey', 'Stan Kerr', 'Sylvester Mowry',
#        'William Congreve', 'Edmund Venables', 'Thomas A Kempis', 'Epictetus',
#        'S. Weir Mitchell', 'Hendrik van Loon', 'Samuel Taylor Coleridge',
#        'Robert F. Murray, Edited by Andrew Lang', 'Stephen Vincent Benet',
#        'Homer and Hesiod', 'Joe Hutsko',
#        'Kate Douglas Smith Wiggin, Illustrated by Claude A. Shepperson',
#        'Valentine Williams', 'William Blades',
#        'Frank Lewis Dyer and Thomas Commerford Martin', 'Robert Service',
#        'Dornford Yates', 'Charles and Mary Lamb', 'Victor MacClure',
#        'Sherwood Anderson', 'The National Atomic Museum',
#        'Sara Jeanette Duncan', 'R. M. Ballantyne', 'Helen Bannerman',
#        'David Magie Cory', 'George Sand',
#        'Miller Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Katherine Mansfield', 'Ida Pfeiffer',
#        'Howard Trueman Copyright laws are changing all over the world, be sure to c',
#        'oject Gutenberg Etext of Study of the King James Bible, McAfee',
#        'William Hazlitt',
#        'Arthur B. Reeve Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Lodovico Ariosto', 'John Fox, Jr.', 'Thomas Jefferson',
#        'Adelaide Anne Procter', 'Charles Whibley', 'Edward Carpenter',
#        'Louise Muhlbach', 'Cal Stewart',
#        'Henry Cabot Lodge, and Theodore Roosevelt', 'Thomas Dixon',
#        'Smyrnaeus Quintus',
#        'e Project Gutenberg Etext of The Journal of Abnormal Psychology Copyright laws are changing all over the world, be sure to check the copyright',
#        'William Hickling Prescott', 'Alexandre Dumas, fils', 'Elbert Hubbard',
#        'Nikolai Vasilievich Gogol', 'Giambattista Basile',
#        'Thomas Alexander Browne, AKA Rolf Boldrewood',
#        'Henry James # in our series by Henry James', 'Homer',
#        'Maynard Barbour', 'Earl Derr Biggers', 'James F. Cooper',
#        'Fulgence Marion', 'E. Charles Vivian', 'Henry Van Dyke',
#        'Joyce Kilmer', 'A. J. O'Reilly',
#        'Andrew Lang, Edited by W. H. Davenport Adams', 'Jerome Lobo',
#        'Coalition for Networked Information', 'Alice Dunbar',
#        'Richard Lovelace', 'John Gower', 'Mary Eleanor Wilkins Freeman',
#        'Abraham Lincoln', 'George Borrow, Illustrated by E. J. Sullivan',
#        'Ivan S. Turgenev', 'United States. Central Intelligence Agency',
#        'Adam Lindsay Gordon', 'Jean Baptiste Racine', 'Harriet E. Wilson',
#        'Winn Schwartau', 'Ellen Robena Field', 'A.C. Seward and Others',
#        'Richard le Gallienne', 'F. Hopkinson Smith',
#        'William D. McClintock and Porter Lander McClintock Copyright laws are chang',
#        'United States Army', 'Apollonius Rhodius',
#        'Charles Dodgson AKA Lewis Carroll',
#        'Martin Luther, translated by Robert E. Smith.',
#        'Voltaire, Edited by Henry Morley',
#        'by (AKA B. M. Sinclair) B. M. Bower', 'William Smith',
#        'Edmund Burke, Edited by Henry Morley', 'William H. Prescott',
#        '(AKA Ralph Iron) Olive Schreiner', 'David Slowinski', 'Ruth Ogden',
#        'Oliver Optic', 'Herbert Allen Giles', 'Prosper Merimee',
#        'oject Gutenberg Etext Use and Need of the Life of C. A. Nation Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Lao-Tze', 'Snorri Sturlason', 'Eliot Gregory', 'Mary Murdoch Mason',
#        'Norman F. Joly', 'David Livingstone',
#        'e Project Gutenberg EBook of Remarks of Mr. Calhoun of South Carolina on the bill to prevent the interference of certain federal officers in elect',
#        'Elizabeth Gaskell # in our series by Elizabeth Gaskell Copyright laws are changing all over th',
#        'oject Gutenberg Etext The Lock and Key Library, Hawthorne, Ed. Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Isabella L. Bird', 'Leo Tolstoi', 'Alexandre Dumas, Pere',
#        'Margaret Hill McCarter', 'Miriam Michelson', 'Edward Lear',
#        'Walter Scott', 'Alfred Lord Tennyson', 'Madame de La Fayette',
#        '(AKA Charlotte, Emily and Anne Bronte) Currer, Ellis, and Acton Bell',
#        'Walter Raleigh', 'Andy Adams', 'Jean Clottes', 'Charles W. Chesnutt',
#        'Alfred Tennyson',
#        'Justus Friedrich Karl Hecker, Edited by Henry Morley, Translated by Benjami',
#        'Samuel Johnson', 'Karl Marx and Friedrich Engels',
#        'Helen Cody Wetmore', 'Max Brand', 'the Lambs', 'Jonathan Swift',
#        'J. M. Bacon', 'Robert Southey', 'Ruth M. Sprague',
#        'Macaulay # in our series by Thomas Babington Macaulay Copyright laws a',
#        'Alfred Joyce Kilmer',
#        'Wagner/Burgoyne The author catalog entries are rather strange, so we included an assortment of inf',
#        'Edward S. Ellis et. al.',
#        'Martin Luther # in our series by Martin Luther Copyright laws are changing all over the wor',
#        'George Whale', 'Odd de Presno', 'Richard F. Burton',
#        'Chretien de Troyes', 'Grace Isabel Colbron, and Augusta Groner',
#        'E. H. Chapin', 'Florence Converse',
#        'Joshua Reynolds, Edited by Henry Morley', 'Karl Marx',
#        'Robert Hichens', 'onia and Assyria, by Theophilus G. Pinches',
#        'James Boswell', 'Mary Johnston',
#        'oject Gutenberg Etext Increasing Human Efficiency In Business Copyright laws are changing all over the world, be sure to check the copyright',
#        'Enrico Ferri', 'Mr. and Mrs. Haldeman-Julius', 'Lord Dunsany',
#        'Margaret Deland', 'Eros Urides and J. L. Kennon',
#        'Bishop Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'George M. Gould and Walter Lytle Pyle', 'Hjalmar Hjorth Boysen',
#        'J. Walker McSpadden', 'C. F. Volney', 'Wilfred Owen',
#        'Charlotte Perkins Stetson Gilman',
#        'Pi (to million digits), by Yasumasa Kanada',
#        'English Authors: Africa, by Various',
#        'J. M. Synge # in our series by J. M. Synge Copyright laws are changing all over the world',
#        'Alice Freeman Palmer', 'Benjamin Cardozo', 'P. J. Proudhon',
#        'Ellen Key', 'John McCrae',
#        'Stephen Crane # in our series by Stephen Crane Copyright laws are changing all over the worl',
#        'Diane and Don Nafis, dnafis@nazlo.com The Project Gutenberg Etext of James Otis The Pre-Revolutionist by John Clark Ridpath Co',
#        'Alexandre Dumas (Pere)', 'E. F. Benson', 'Gertrude Atherton',
#        'Mitzi Perdue', 'he Project Gutenberg EBook of The King James Bible',
#        'Robert Harris', 'MICRA, Inc. Copyri', 'Royall Tyler',
#        'Robert Williams Wood', 'Wu Tingfang', 'Henry H. Snelling',
#        'Geoffrey Chaucer', 'Jeffery Farnol', 'Friedrich Schiller',
#        'William Godwin', 'Carl Maag and Steve Rohrer',
#        'Dinah Maria Mulock Craik', 'John A. Carpenter', 'J. Storer Clouston',
#        'Margaret Sanger', 'Thoma', 'Frank Tymon', 'Guy de Maupassant',
#        'John Bunyan', 'Maurice LeBlanc', 'Aesop', 'Sarojini Naidu',
#        'Harry Alonzo Cushing, vol. III. Copyright laws are cha',
#        'William Roscoe Thayer Copyright laws are changing all over the world, be s',
#        'Edmund G. Ross', 'Elizabeth Cleghorn Gaskell',
#        'Brian Oswald Donn-Byrne', 'Helen Beecher Long', 'G. Harvey Ralphson',
#        'James Stephens', 'Michael Husted', 'Dan Scavelle',
#        'Thomas Papanikolaou', 'by Edward Jenkins', 'Conrad Aiken',
#        'Natalie Sumner Lincoln', 'ENTY YEARS AFTER',
#        'Etienne Leon Lamothe-Langon',
#        'oject Gutenberg Etext of The Dore' Lectures on Mental Science Copyright laws are changing all over the world, be sure to check the copyright',
#        'John Masefield', 'Theophile Gautier',
#        'Jerry Bonnell and Robert Nemiroff', 'Zitkala-Sa',
#        'Frederick A. Talbot', 'Frances Jenkins Olcott',
#        'Willa Cather and Alfred Noyes', 'H. L. Mencken',
#        'Fannie Isabelle Sherrick',
#        'L. Cranmer-Byng Please take a look at the important information in this header. We encourage you',
#        'Hilda Conkling', 'Marie L. McLaughlin', 'Tadashi Nakashima',
#        'William Beckford, Edited by Henry Morley', 'Anna Katherine Green',
#        'Robert Graves', 'St. Jude, R. U. Sirius, Bart Nagel', 'Henry Timrod',
#        'Freeman Wills Crofts', 'Lafcadio Hearn', 'Emma Goldman', 'LeFebure',
#        'Arthur Brisbane', 'Maria Edgeworth, Edited by Henry Morley',
#        'Madame de Lafayette',
#        'e Project Gutenberg Etext of Popular Science Monthly Volume Copyright laws are changing all over the world, be sure to check the copyrig',
#        '(AKA Clive Hamilton) C. S. Lewis', 'Martha Young',
#        'Harriet Beecher Stowe', 'Russell H. Conwell', 'Frank Frankfort Moore',
#        'J. Stark Munro',
#        'General William Booth [ The founder of the Salvation Army tells of his philoso',
#        'English Authors: Orient, by Various', 'James Lane Allen', 'A. Merritt',
#        'Benjamin Franklin', 'John Breckinridge Ellis', 'Martha Summerhayes',
#        'James J. Davis', 'Alexander Pope', 'W.J. Jackman and Thos. H. Russell',
#        'B.M. Sinclair, AKA B.M. Bower', 'John Dryden', 'Robert Herrick',
#        'Walter Hawkins', 'Franz Josef Haydn', 'Mrs. Mary Rowlandson',
#        'Plaatje Copyright laws are changing all over the world, be sure to check the copyright',
#        'Dr. Martin Luther', 'Giuseppe Salza',
#        'Benjamin Rumford Copyright laws are changing all over the world, be sure to',
#        'H. Rider Haggard # in our series by H. Rider Haggard',
#        's, by Edgar Rice Burroughs', 'George Smith', 'Frank T. Bullen',
#        '(may be spurious) Plato', 'Gilbert K. Chesterton', 'E. R. Punshon',
#        'R. D. Blackmore', 'Gail Hamilton', 'Jeffrey Farnol', 'Johanna Spyri',
#        'Philip Melancthon', 'Project Gutenberg', 'A. B. Paterson',
#        'e Project Gutenberg Etext of Organic Syntheses, Conant, Editor Caveat: Some numbers did not OCR correctly and may not have been corrected duri',
#        'Robert Burns', 'George W. Sands', 'Mark E. Laxer', 'Edwin A. Abbot',
#        'Frances E. W. Harper', 'E. V. Lucas',
#        'John M. Coulter Copyright laws are changing all over the world, be sure to c',
#        'William Congreve, Edited by G. S. Street',
#        'Tilden Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Library of Congress',
#        'Edwin A. Abbott There are several editions of this ebook in the Project Gutenberg collection. Various',
#        'Marie Belloc Lowndes', 'Sir John Tenniel', 'Thomas Nelson Page',
#        'Bruce Sterling', 'J. Munro', 'Clarence Edgar Johnson',
#        'Hjalmar Hjorth Boyesen', 'William and Ellen Craft', 'Fa-Hsien',
#        'Charles Oliver', 'Ilya Tolstoy', 'Mariano Azuela', 'John Tyndall',
#        'John Ruskin.', 'Emile Zola', 'Chretien DeTroyes', 'Eden Phillpotts',
#        'Owen Meredith', 'Chauncey M. Depew', 'Lucius Apuleius',
#        'Thomas More, Edited by Henry Morley', 'Anna Howard Shaw',
#        '(AKA Elia Wilkinson) Elia W. Peattie', 'Helen Keller',
#        'Alexander Hamilton, John Jay, and James Madison',
#        'Arthur Ransome # in our series by Arthur Ransome Copyright laws are changing all over the wo',
#        'Avery Hopwood and Mary Roberts Rinehart', 'Melvin L. Severy',
#        'B.M. Sinclair, AKA B. M. Bower', 'Myrtle Reed', 'Joseph McCabe',
#        'Helen Nicolay', 'A. A. Milne', 'John Filson',
#        'Electronic Frontier Foundation',
#        'Gorky # in our series, by Maxim Gorky Copyright laws are changing all over the wor',
#        'Richard McGowan', 'Plutarch', 'Oliver Wendell Holmes',
#        'David Herbert Lawrence', 'John William Draper', 'E THREE MUSKETEERS',
#        'Rex Stout', 'Ralph Parlette', 'William Alexander Linn',
#        'Thomas Love Peacock', 'Library of Congress Copyright Office',
#        'John Philip Sousa', 'C. J. Cutcliffe Hyne', 'Padraic Colum',
#        'Nettie Garmer Barker',
#        'Alexander Hamilton and John Jay and James Madison', 'Lew Wallace',
#        'Kakuzo Okakura', 'Joseph Rodman Drake',
#        'Oscar Wilde, Edited by Robert Ross', 'Rene Doumic',
#        'Herbert N. Casson',
#        'Neltje Blanchan Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Lucan', 'Elizabeth Gaskell', 'Daniel Defoe, Edited by Henry Morley',
#        'Cicero', 'Eleanor Farjeon',
#        'Carvalho Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Johann Wolfgang Von Goethe', 'Phillis Wheatley',
#        'St. John of Damascus', 'Kate Chopin',
#        'U.S. Census of Population and Housing and U.S. Dept. of Commerce, Econ',
#        'Emma Wolf',
#        'Geoffrey Chaucer Copyright laws are changing all over the world, be sure t',
#        'e Project Gutenberg Etext "Divina Commedia di Dante: Inferno" In Italian with no accents Please see my notes about various versions b',
#        'The Princess Der Ling', 'Henry Fielding',
#        '(AKA Kate Douglas Riggs) Kate Douglas Wiggin', 'Hiram Corson',
#        'John Fox Jr.', 'Rev. James MacCaffrey Copyright laws',
#        'Sextus Propertius', 'Scott Hemphill', 'Victor Cherbuliez',
#        'Bayard Taylor', 'Donald Mackenzie Wallace', 'Richard de Bury',
#        'Ferdinand Ossendowski', 'Hall Caine', 'Mary Mapes Dodge',
#        'Sarah Orne Jewett',
#        'United States Arms Control and Disarmament Agency',
#        'J. Fitzgerald Molloy', 'Jonathan Swift, Edited by Henry Morley',
#        'James Fenimore Cooper # in our series by James Fenimore Cooper Copyright laws are changing all ove',
#        'e Project Gutenberg Etext Divina Commedia di Dante: Purgatorio In Italian with no accents Please see my notes about various versions',
#        'Francois Rabelais', 'John Quincy Adams', 'Howard R. Garis',
#        'Edouard le Roy', 'e Project Gutenberg EBook of The Holy Bible.',
#        'Mary Esther Miller MacGregor, AKA Marion Keith', 'James Branch Cabell',
#        'Baruch Spinoza',
#        'Jonathan Nield Copyright laws are changing all over the world, be sure to ch',
#        'Don Marquis Copyright laws are changing all over the world',
#        'William S. Gilbert',
#        'Captain Marryat # in our series by Captain Marryat Copyright laws are changing all over the w',
#        'Gildas', 'Louise de la Ramee (AKA Ouida)',
#        'Miss Mulock Pseudonym of Maria Dinah Craik', 'W. H. Hudson',
#        'Joel Chandler Harris Copyright laws are changing all over the world. Be sure to check the copyrigh',
#        'Dumont Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Unknown Icelanders', 'Thomas Burke', 'Alexander H. Japp', 'Sun Tzu',
#        'By Kate Douglas Wiggin', 'Joseph A. Munk', 'John N. Reynolds',
#        'Margaret Pollock Sherwood', 'M. G. Lewis', 'Friedrich Nietzsche',
#        'John Goodwin', 'George Borrow, Edited by T. H. Darlow',
#        'Joel Benton. Copyright laws are changing al', 'Omar Khayyam',
#        'Norman Coombs', 'Bernardin de Saint Pierre', 'Mine, by Margaret Mayo',
#        'Charles Babbage', 'John Murray and Mills Miller', 'Dorothy Kilner',
#        'Susanna Rowson', 'Thomas Hughes', 'Francis Bacon', 'Arthur Ransome',
#        'James Thomson', 'Fyodor Dostoyevsky', 'Margaret E. Sangster',
#        'Elbridge S. Brooks', 'Lazarillo of Tormes', 'Arnold Bennett',
#        'Lucy Larcom', 'Henry W. Longfellow', 'B.M. Bower', 'Pierre Loti',
#        'Noah Brooks', 'Eugene Field', 'Lewis Roth',
#        'Wm J. Kountz, Jr. Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Edmond Rostand', 'James M. Barrie', 'Edwin L. Arnold',
#        'Sinclair Lewis', 'James Hogg', 'Cunninghame Graham',
#        'Edward George Bulwer-Lytton', 'Harold MacGrath', 'Ross Kay',
#        'Mrs. W. G. Waters', 'William J. Claxton',
#        '"Elizabeth", AKA Marie Annette Beauchamp', 'Sydney Waterlow',
#        'Hans Christian Andersen', 'Herman Melville', 'Carl von Clausewitz',
#        'John Lawson',
#        'Jane Addams Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Thomas Hart Benton', 'Chester K. Steele', 'Francis Parkman, Jr.',
#        'William Osler', 'Joseph E. Badger, Jr.',
#        '(His Son) Captain Robert E. Lee', 'Alan Seeger', 'Amy Steedman',
#        'Robert Louis Stevenson, Illustrated by Walter Crane',
#        'William Gilmore Simms', 'Mary Austin', 'Edward P. Roe',
#        'Frances Hodgson Burnett, Illustrated by F. C. Yohn', 'Stephen Levy',
#        'Christopher Marlowe', 'Arthur B. Reeve',
#        'e Project Gutenberg Etext of Stories from Everybody's Magazine From the issues of Everybody's Magazine Copyright laws are changing all o',
#        'Gary Mann', 'Henry Kendall', 'L. Frank Baum.',
#        'e Project Gutenberg Etext of An Anthology of Australian Verse Copyright laws are changing all over the world, be sure to check the copyright',
#        'Jean-Baptiste Poquelin Moliere', 'Burbank L. Todd',
#        'Gilbert Keith Chesterton', 'Arthur Machen', 'H. Barber',
#        'Franklin Delano Roosevelt', 'Vicente Blasco Ibanez', 'John Dewey',
#        'Step, by The American Tract Society', 'Andrew Lang.',
#        'Arthur Hugh Clough', 'L. Adams Beck', 'Richard Brinsley Sheridan',
#        'George Gissing', 'Rupert Brooke',
#        'George Iles Copyright laws are changing all over the world, be sure to',
#        'Thomas Holmes', 'Oliver Goldsmith', 'Alfred, Lord Tennyson',
#        'J. Henri Fabre, Translated by Alexander Teixeira de Mattos',
#        'White Sands Missile Range Public Affairs Office', 'Anna Sewell',
#        'Niccolo Machiavelli', 'Eliza Burt Gamble', 'Rutherford Platt',
#        'Christopher Evans',
#        'e Project Gutenberg Etext of The Narrative of Sojourner Truth',
#        'T. S. Eliot',
#        'oject Gutenberg's Etext of The Life of General Francis Marion',
#        'European Union', 'Sir Walter Raleigh', 'Mrs. Sutherland Orr',
#        'Hugh Latimer, Edited by Henry Morley', 'Nathaniel Wright Stephenson',
#        'Edgar B P Darlington Copyright laws', 'S. A. Reilly', 'Ed Krol',
#        'J. E. Hutton', 'Marvin Dana', 'Saxo Grammaticus ("Saxo the Learned")',
#        'Joanot Martorell and Marti Johan d'Galba', 'Brendan P. Kehoe',
#        'Peter Mark Roget', 'Frank Bird Linderman',
#        'Edgar B. P. Darlington Copyrig',
#        'O. Henry, Illustrated by H. C. Greening and May Wilson Preston',
#        'Nicolo Machiavelli', 'Joseph-Pierre Proudhon', 'Edward Bellamy',
#        'Percival Lowell', 'Henry Clay', 'Henry David Thoreau',
#        'An Anonymous Young Girl', 'Michael Hart',
#        'on And Egypt, by Leonard W. King', 'M. Y. Lermontov',
#        'Samuel Adams (# in our series by Samuel Adams) Copyright law',
#        'Calamity Jane', 'Feodor Dostoevsky', 'R. S. Ball',
#        'Henry Benjamin Wheatley',
#        'oject Gutenberg Etext: A Journey in Other Worlds, J. J. Astor Copyright laws are changing all over the world, be sure to check the copyrigh',
#        'Browning, Elizabeth Barrett',
#        'George MacDonald (# in our series by George MacDonald) Copyright laws are changing all over t',
#        'E. S. Brooks', 'J. Frank Dobie', 'A. O. Brownson',
#        'Louis de Rougemont', 'Sarah Fielding',
#        'Smiles # in our series by Samuel Smiles Copyright laws are changing all over the wo',
#        'Adelaide L. Fries', 'Nennius', 'Thorstein Veblen',
#        'Joseph A. Altsheler', 'Gideon Wurdz', 'August Niemann',
#        'Margaret Mayo', 'Adelaide Anne Procter, et al',
#        'Elizabeth Drew Stoddard', 'Lucretius', 'Torquato Tasso',
#        'Robert Louis Stevenson, et al', 'William J. Long',
#        'George Wharton James', 'Robert Louis Stevenson and Lloyde Osbourne',
#        'John Charles McNeill', 'Johann Wolfgang von Goethe',
#        'Mary Wollstonecraft', 'Charlotte M. Braeme'],
#       dtype='object')

# %%
#make corrections
corrections = ['Hesther Lynch Piozzi','Beatrix Potter','Susan Fenimore Cooper','Baker','Hale','Cunninghame Graham','Charles Oliver', 'William Makepeace Thackeray', 
               "Shakespeare", 'James Russell Lowell', 'Henry Wadsworth Longfellow', 'Andrew Dickson White', 'Ayn Rand', 'Fannie Isabelle Sherrick', 'John Lord', 'James Lane Allen',
               'Jack London', 'William Wells Brown', 'Thomas A Kempis', "Alexander Pope", 'Louis Ginzberg', 'Jerome K. Jerome', 'Maurice Maeterlinck', 'George Wharton James', 
                'Rudyard Kipling', 'Jerome Lobo', 'James F. Cooper', 'Charles Dickens', 'Upton Sinclair', 'Johanna Spyri', 'William and Ellen Craft', 
               'James Whitcomb Riley', 'Helen Beecher Long', 'Joseph-Pierre Proudhon', 'Arthur Brisbane', 'Julian Hawthorne', 'R. M. Ballantyne']
for corr in corrections:
    df.loc[df.author.str.contains(corr), 'author'] = corr

# %%
#unknowns, aliases, etc.
unknowns = [' and ', 'various', 'anonymous', 'unknown', 'enty years after', 'gutenberg', '\(', 'edited', 'illustrated', "copyright"]
various = df.loc[df.author.str.lower().str.contains('|'.join(unknowns))]

df.loc[df.author.str.lower().str.contains('|'.join(unknowns))] = float("NaN")
df.dropna(inplace=True)

#aliases that are labeled with AKA. 
df.loc[df.author.str.contains('AKA')] = float("NaN")
df.dropna(inplace=True)

# %%
#Reduce author counts to fifty. 
author_counts = df.author.value_counts()[0:50]
keep = author_counts[author_counts.values > 3]

#reassign the dataframe to these values. 
df = df[df.author.isin(author_counts.index)].copy()

# %%
#Remove all the works after the first three, because we only want three of them. 
for a in keep.index:
    remove_index = df[df.author.isin([a])][3:].index
    df.drop(remove_index, inplace=True)

# %%
#Number of documents.
df.author.value_counts().sum()
# Out:
# 150

# %% [markdown]
# The NLP generated some kind of an error message when the text exceeded a number of characters.
# The following steps were taken:
# > Increased page file size.
#
# > Set PC properties to maximize peformance.
#
# > Reduced the variable t to translate at that amount.
#
# *note: originally I had run nlp against all 2,000 records to set them out as documents. It took over four hours to process all 2k records, the large dataset caused frequent lagging and I would often have to reboot my computer; slowing down the project.*

# %%
#Now is the time. Turn these text fields into documents.
nlp = en_core_web_sm.load()
doc = []
author = []
i = 0
df['doc'] = ""
df['no_stop'] = ""
# All the processing work takes place below, so it may take a while.
for index, t in df.iterrows():
    print(f'{dt.datetime.now().strftime("%d/%m/%Y %H:%M:%S")} working on doc {i}')
    #try to process the text file into a document. Skip it if it can't. As many as possible.
    try:
        #500000 characters seems long enough for this exercise. I just want to identify the author - which is a text field labled "Author:" or whoever is after the "by" statement. 
        t['doc'] = nlp(t.text[0:500000])
        t['no_stop'] =  [token for token in t.doc if not token.is_stop]
        i += 1
    except:
        i += 1
        print("encountered an exception, skipping to next document.")
# Out:
# 27/12/2020 15:38:34 working on doc 0
# 27/12/2020 15:38:48 working on doc 1
# 27/12/2020 15:39:00 working on doc 2
# 27/12/2020 15:39:09 working on doc 3
# 27/12/2020 15:39:13 working on doc 4
# 27/12/2020 15:39:17 working on doc 5
# 27/12/2020 15:39:29 working on doc 6
# 27/12/2020 15:39:42 working on doc 7
# 27/12/2020 15:39:53 working on doc 8
# 27/12/2020 15:40:00 working on doc 9
# 27/12/2020 15:40:05 working on doc 10
# 27/12/2020 15:40:15 working on doc 11
# 27/12/2020 15:40:26 working on doc 12
# 27/12/2020 15:40:34 working on doc 13
# 27/12/2020 15:40:46 working on doc 14
# 27/12/2020 15:40:56 working on doc 15
# 27/12/2020 15:41:08 working on doc 16
# 27/12/2020 15:41:21 working on doc 17
# 27/12/2020 15:41:33 working on doc 18
# 27/12/2020 15:41:44 working on doc 19
# 27/12/2020 15:41:56 working on doc 20
# 27/12/2020 15:42:00 working on doc 21
# 27/12/2020 15:42:02 working on doc 22
# 27/12/2020 15:42:05 working on doc 23
# 27/12/2020 15:42:16 working on doc 24
# 27/12/2020 15:42:26 working on doc 25
# 27/12/2020 15:42:37 working on doc 26
# 27/12/2020 15:42:52 working on doc 27
# 27/12/2020 15:42:59 working on doc 28
# 27/12/2020 15:43:13 working on doc 29
# 27/12/2020 15:43:21 working on doc 30
# 27/12/2020 15:43:31 working on doc 31
# 27/12/2020 15:43:43 working on doc 32
# 27/12/2020 15:43:57 working on doc 33
# 27/12/2020 15:44:09 working on doc 34
# 27/12/2020 15:44:18 working on doc 35
# 27/12/2020 15:44:23 working on doc 36
# 27/12/2020 15:44:29 working on doc 37
# 27/12/2020 15:44:32 working on doc 38
# 27/12/2020 15:44:46 working on doc 39
# 27/12/2020 15:44:58 working on doc 40
# 27/12/2020 15:45:11 working on doc 41
# 27/12/2020 15:45:12 working on doc 42
# 27/12/2020 15:45:20 working on doc 43
# 27/12/2020 15:45:29 working on doc 44
# 27/12/2020 15:45:33 working on doc 45
# 27/12/2020 15:45:46 working on doc 46
# 27/12/2020 15:45:58 working on doc 47
# 27/12/2020 15:46:08 working on doc 48
# 27/12/2020 15:46:14 working on doc 49
# 27/12/2020 15:46:24 working on doc 50
# 27/12/2020 15:46:34 working on doc 51
# 27/12/2020 15:46:38 working on doc 52
# 27/12/2020 15:46:48 working on doc 53
# 27/12/2020 15:46:50 working on doc 54
# 27/12/2020 15:46:54 working on doc 55
# 27/12/2020 15:47:02 working on doc 56
# 27/12/2020 15:47:11 working on doc 57
# 27/12/2020 15:47:21 working on doc 58
# 27/12/2020 15:47:27 working on doc 59
# 27/12/2020 15:47:41 working on doc 60
# 27/12/2020 15:47:46 working on doc 61
# 27/12/2020 15:48:00 working on doc 62
# 27/12/2020 15:48:11 working on doc 63
# 27/12/2020 15:48:17 working on doc 64
# 27/12/2020 15:48:24 working on doc 65
# 27/12/2020 15:48:32 working on doc 66
# 27/12/2020 15:48:45 working on doc 67
# 27/12/2020 15:48:56 working on doc 68
# 27/12/2020 15:49:03 working on doc 69
# 27/12/2020 15:49:16 working on doc 70
# 27/12/2020 15:49:29 working on doc 71
# 27/12/2020 15:49:40 working on doc 72
# 27/12/2020 15:49:51 working on doc 73
# 27/12/2020 15:50:03 working on doc 74
# 27/12/2020 15:50:17 working on doc 75
# 27/12/2020 15:50:30 working on doc 76
# 27/12/2020 15:50:32 working on doc 77
# 27/12/2020 15:50:45 working on doc 78
# 27/12/2020 15:50:56 working on doc 79
# 27/12/2020 15:51:02 working on doc 80
# 27/12/2020 15:51:05 working on doc 81
# 27/12/2020 15:51:18 working on doc 82
# 27/12/2020 15:51:26 working on doc 83
# 27/12/2020 15:51:35 working on doc 84
# 27/12/2020 15:51:37 working on doc 85
# 27/12/2020 15:51:38 working on doc 86
# 27/12/2020 15:51:41 working on doc 87
# 27/12/2020 15:51:43 working on doc 88
# 27/12/2020 15:51:46 working on doc 89
# 27/12/2020 15:51:50 working on doc 90
# 27/12/2020 15:51:57 working on doc 91
# 27/12/2020 15:51:58 working on doc 92
# 27/12/2020 15:52:00 working on doc 93
# 27/12/2020 15:52:06 working on doc 94
# 27/12/2020 15:52:11 working on doc 95
# 27/12/2020 15:52:24 working on doc 96
# 27/12/2020 15:52:30 working on doc 97
# 27/12/2020 15:52:42 working on doc 98
# 27/12/2020 15:52:49 working on doc 99
# 27/12/2020 15:52:56 working on doc 100
# 27/12/2020 15:52:58 working on doc 101
# 27/12/2020 15:53:01 working on doc 102
# 27/12/2020 15:53:14 working on doc 103
# 27/12/2020 15:53:19 working on doc 104
# 27/12/2020 15:53:22 working on doc 105
# 27/12/2020 15:53:24 working on doc 106
# 27/12/2020 15:53:26 working on doc 107
# 27/12/2020 15:53:39 working on doc 108
# 27/12/2020 15:53:51 working on doc 109
# 27/12/2020 15:54:04 working on doc 110
# 27/12/2020 15:54:09 working on doc 111
# 27/12/2020 15:54:18 working on doc 112
# 27/12/2020 15:54:21 working on doc 113
# 27/12/2020 15:54:33 working on doc 114
# 27/12/2020 15:54:34 working on doc 115
# 27/12/2020 15:54:46 working on doc 116
# 27/12/2020 15:54:48 working on doc 117
# 27/12/2020 15:54:49 working on doc 118
# 27/12/2020 15:54:51 working on doc 119
# 27/12/2020 15:54:59 working on doc 120
# 27/12/2020 15:55:02 working on doc 121
# 27/12/2020 15:55:14 working on doc 122
# 27/12/2020 15:55:17 working on doc 123
# 27/12/2020 15:55:29 working on doc 124
# 27/12/2020 15:55:42 working on doc 125
# 27/12/2020 15:55:54 working on doc 126
# 27/12/2020 15:56:05 working on doc 127
# 27/12/2020 15:56:16 working on doc 128
# 27/12/2020 15:56:23 working on doc 129
# 27/12/2020 15:56:28 working on doc 130
# 27/12/2020 15:56:39 working on doc 131
# 27/12/2020 15:56:49 working on doc 132
# 27/12/2020 15:57:04 working on doc 133
# 27/12/2020 15:57:14 working on doc 134
# 27/12/2020 15:57:28 working on doc 135
# 27/12/2020 15:57:30 working on doc 136
# 27/12/2020 15:57:42 working on doc 137
# 27/12/2020 15:57:56 working on doc 138
# 27/12/2020 15:57:58 working on doc 139
# 27/12/2020 15:58:01 working on doc 140
# 27/12/2020 15:58:12 working on doc 141
# 27/12/2020 15:58:26 working on doc 142
# 27/12/2020 15:58:37 working on doc 143
# 27/12/2020 15:58:50 working on doc 144
# 27/12/2020 15:58:51 working on doc 145
# 27/12/2020 15:59:03 working on doc 146
# 27/12/2020 15:59:14 working on doc 147
# 27/12/2020 15:59:22 working on doc 148
# 27/12/2020 15:59:25 working on doc 149

# %%
dist_plot = df[['author', 'doc']].iloc[0]
length = [len(w) for w in dist_plot.doc]
fdist = nltk.FreqDist(length)
fdist.plot(title=dist_plot.author)
# Out:
# <AxesSubplot:title={'center':'Thomas Hardy'}, xlabel='Samples', ylabel='Counts'>

# %%
# Instantiate your list of the most common words
word_freq = word_frequencies(dist_plot.doc).most_common(10)
print(f'Word Frequencies count for {dist_plot.author} is:\n {word_freq}')
# Out:
# Word Frequencies count for Thomas Hardy is:
#  [('\r\n', 9824), ('the', 4491), ('and', 2507), ('a', 2476), ('of', 2400), ('to', 2235), ('I', 1412), ('in', 1409), ('was', 1262), ('you', 926)]

# %%
#Pickle the author and doc in case I have to reboot. 
timer('pickling dataframes.')

with open(filename, 'wb') as f:
    pickle.dump(df[['author', 'doc']], f)

timer('done pickling dataframes')
# Out:
# 27/12/2020 15:59:32: pickling dataframes.
# 27/12/2020 16:01:13: done pickling dataframes

# %% [markdown]
# # Feature Engineering
#
# Here is where we engineer features for modeling.

# %%
#This is a convenient function for creating a new dataframe, should I run into an error. 
#This function returns a dataframe with sentences from the pickle file that was saved to the filename location.

def get_docs(filename):
    with open(filename, 'rb') as f:
        df = pickle.load(f)
    list_sentences = []

    for index, row in df.iterrows():
        list_sentences += ([[sent, row.author, row.doc[0:500]] for sent in row.doc.sents])

    # Combine the sentences from the two novels into one DataFrame
    sentences = pd.DataFrame(list_sentences, columns = ["sentences", "author", 'title'])
    
    # Get rid of stop words and punctuation and lemmatize the tokens
    for i, sentence in enumerate(sentences["sentences"]):
        sentences.loc[i, "sentences"] = [token.lemma_ for token in sentence if not token.is_punct and not token.is_stop]
    return sentences

# %%
#TO DO: If document reboots: Change to sentences = get_docs(filename) and delete the cell below this one.
# Grouping by sentences for each of these documents. 
list_sentences = []

for index, row in df.iterrows():
    list_sentences += ([[sent, row.author, row.doc[0:500]] for sent in row.doc.sents])
    
# Combine the sentences from the two novels into one DataFrame
sentences = pd.DataFrame(list_sentences, columns = ["sentences", "author", 'title'])
sentences.head()
# Out:
#                                            sentences        author  \
# 0  (The, Project, Gutenberg, EBook, of, Far, from...  Thomas Hardy
# 1  (*, *, *, *, *, *, *, *, *, *, *, *, *, *, *, ...  Thomas Hardy
# 2               (THIS, EBOOK, WAS, ONE, OF, PROJECT)  Thomas Hardy
# 3            (GUTENBERG, 'S, EARLY, FILES, PRODUCED)  Thomas Hardy
# 4                                               (AT)  Thomas Hardy
#
#                                                title
# 0  (The, Project, Gutenberg, EBook, of, Far, from...
# 1  (The, Project, Gutenberg, EBook, of, Far, from...
# 2  (The, Project, Gutenberg, EBook, of, Far, from...
# 3  (The, Project, Gutenberg, EBook, of, Far, from...
# 4  (The, Project, Gutenberg, EBook, of, Far, from...

# %%
# Get rid of stop words and punctuation and lemmatize the tokens
for i, sentence in enumerate(sentences["sentences"]):
    sentences.loc[i, "sentences"] = [token.lemma_ for token in sentence if not token.is_punct and not token.is_stop]

# %% [markdown]
# # Bag of Words

# %% [markdown]
# For bag of words, I have to troubleshoot a memory error.
#
# `MemoryError: Unable to allocate 27.0 TiB for an array with shape (6566859, 565300) and data type int64`
#
# Step One: Reduce the size by changing the data type.
#
# > Another error arises when I attempt to mask the shape to an int8.
#
# >```
# import numpy as np
# mask = np.zeros(X.shape,dtype='uint8')
# >```
#
# >`MemoryError: Unable to allocate 3.38 TiB for an array with shape (6566859, 565300) and data type uint8`
#
#
# Step Two: Reduce content by reducing authors.
# > Project requirements said ten authors and thousands of texts, with at least seven novels.
#
# > I returned to the data cleaning process to eliminate various/anonymous/unknown authors.
#
# > I still get an error.
#
# > `MemoryError: Unable to allocate 16.1 TiB for an array with shape (5928859, 373831) and data type int64`
#
# Step Three: Reduce content again by reducing authors in a way such that the dataset is more balanced.
# >I returned to the data cleaning process to reduce the number of works of those largest authors to three or four.
#
# >Received a similar memory error.
#
# Step Four: Skip the dataframe, train the model.
#
# > Received a similar memory error and the entire system locked up.
#
# Step Five: Reduce the number of authors.
# > ```Unable to allocate 7.31 GiB for an array with shape (2952352, 665) and data type int32```
#
# > Return to data cleaning and choose the top 100 authors. Decrease steadily until the program runs.
#
# Step Six: After data cleaning down to 50 authors; I'm fed up - reduce author count by ten until it processes or I have ten authors, whichever comes first. If I get down to ten authors: I'll be forced to reduce the number of documents. Cross that bridge at step seven.
#
# In the interest of keeping things easy and to the point; I'll be refraining from adding the error messages. The logistic regression was taking an excessive amount of time to run. I attempted to shape the data into a dataframe again and received an error mentioning 2.77 TiB for 100 authors.

# %%
y = sentences['author']
X = sentences['sentences']

# %%
bow_df = pd.DataFrame(X, columns=vectorizer.get_feature_names())
bow_sents = pd.concat([bow_df, sentences[["text", "author"]]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1670                 blocks = [
# -> 1671                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1672                 ]
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2743
# -> 2744     return klass(values, ndim=ndim, placement=placement)
#    2745
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     130             raise ValueError(
# --> 131                 f"Wrong number of items passed {len(self.values)}, "
#     132                 f"placement implies {len(self.mgr_locs)}"
#
# ValueError: Wrong number of items passed 1, placement implies 100652
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-e4651a42305b> in <module>
# ----> 1 bow_df = pd.DataFrame(mask, columns=vectorizer.get_feature_names())
#       2 bow_sents = pd.concat([bow_df, sentences[["text", "author"]]], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
# --> 497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     498
#     499         # For data is list-like, or Iterable (will consume into list)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     232         block_values = [values]
#     233
# --> 234     return create_block_manager_from_blocks(block_values, [columns, index])
#     235
#     236
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1679         blocks = [getattr(b, "values", b) for b in blocks]
#    1680         tot_items = sum(b.shape[0] for b in blocks)
# -> 1681         raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1682
#    1683
#
# ValueError: Shape of passed values is (1318116, 1), indices imply (1318116, 100652)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

vectorizer = CountVectorizer(analyzer='word')
X_train = vectorizer.fit_transform(X_train.astype(str))
X_test = vectorizer.transform(X_test.astype(str))

# %%
#Test on logistic regression to see if it runs. Expand from here. 
lr = LogisticRegression()
lr.fit(X_train, y_train)
print(classification_report(y_test, lr.predict(X_test)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-3da6089501ab> in <module>
#       1 #Test on logistic regression to see if it runs. Expand from here.
#       2 lr = LogisticRegression()
# ----> 3 lr.fit(X_train, y_train)
#       4 print(classification_report(y_test, lr.predict(X_test)))
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1415                       penalty=penalty, max_squared_sum=max_squared_sum,
#    1416                       sample_weight=sample_weight)
# -> 1417             for class_, warm_start_coef_ in zip(classes_, warm_start_coef))
#    1418
#    1419         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
#    1042                 self._iterating = self._original_iterator is not None
#    1043
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     758                 func, w0, method="L-BFGS-B", jac=True,
#     759                 args=(X, target, 1. / C, sample_weight),
# --> 760                 options={"iprint": iprint, "gtol": tol, "maxiter": max_iter}
#     761             )
#     762             n_iter_i = _check_optimize_result(
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     616     elif meth == 'l-bfgs-b':
#     617         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 618                                 callback=callback, **options)
#     619     elif meth == 'tnc':
#     620         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# ~\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in func(x, *args)
#     733         target = Y_multi
#     734         if solver == 'lbfgs':
# --> 735             def func(x, *args): return _multinomial_loss_grad(x, *args)[0:2]
#     736         elif solver == 'newton-cg':
#     737             def func(x, *args): return _multinomial_loss(x, *args)[0]
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in _multinomial_loss_grad(w, X, Y, alpha, sample_weight)
#     345     grad = np.zeros((n_classes, n_features + bool(fit_intercept)),
#     346                     dtype=X.dtype)
# --> 347     loss, p, w = _multinomial_loss(w, X, Y, alpha, sample_weight)
#     348     sample_weight = sample_weight[:, np.newaxis]
#     349     diff = sample_weight * (p - Y)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in _multinomial_loss(w, X, Y, alpha, sample_weight)
#     296     p += intercept
#     297     p -= logsumexp(p, axis=1)[:, np.newaxis]
# --> 298     loss = -(sample_weight * Y * p).sum()
#     299     loss += 0.5 * alpha * squared_norm(w)
#     300     p = np.exp(p, p)
#
# KeyboardInterrupt:

# %%
# results = model_results('bow', X_train.toarray(), X_test.toarray(), y_train, y_test)
# results

# %%
#Some constant variables for parameter settings. 
#cross validation, constant parameter
cv = 5

#multiclass
mc = ['auto', 'ovr', 'multinomial']
#solver
sv = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
#penalty
py = ['l1', 'l2', 'elasticnet', 'none']
#criterion
cn = ['gini', 'entropy']
#max_features
mf = ['auto', 'sqrt', 'log2']
#splitter
sr = ['best', 'random']
#max_depth
md = [5, 7, 15, 29] 
#n_estimators
ne = [n+50 for n in range(50, 500, 50)]

# %%
#logistic regression
lrp = {    "lr__multi_class": mc, 
           "lr__solver": sv,
           'lr__penalty' : py,
      }
#decision tree
dtp = {
           'dt__criterion': cn,
           'dt__max_features': mf,
           'dt__splitter':sr, 
           'dt__max_depth': md     
}
#K Nearest Neighbors
knnp = {
           'knn__n_neighbors': [3, 9, 39, 12],
           'knn__weights': ['uniform', 'distance'],
           'knn__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'], 
           'knn__leaf_size': [30, 12, 9, 3, 17],  
           'knn__metric': ['mahalanobis','euclidean', 'manhattan', 'chebyshev', 'minkowski', 'seuclidean'],  
}
#Support Vector Classifier
svp = {
          'sv__kernel': ['linear', 'rbf'],
          'sv__break_ties': [True, False],
}
#Random Forest Classifier 
rfp = {
           'rf__criterion': cn,
           'rf__max_features': mf,
           'rf__oob_score':[True, False], 
           'rf__max_depth': md,
           'rf__n_estimators': ne,     
}
#gradient boost 
gbp = {    'gb__criterion': ['friedman_mse', 'mse', 'mae'],
           'gb__max_features': mf,
           'gb__max_depth': md, 
           'gb__n_estimators': ne
          }
transform = { 'vectorizer__analyzer': word }

# %%
from sklearn.naive_bayes import ComplementNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
#Naive Bayes Update pipeline with parameters and classifiers.
pipeline = Pipeline([('vectorizer', CountVectorizer(analyzer='word')), ('nb', ComplementNB())])
params = transform
search = GridSearchCV(pipeline, params, cv=cv)
print(f'{dt.datetime.now().strftime("%d/%m/%Y %H:%M:%S")}, started grid search')
search.fit(X_train, y_train)
print(f'{dt.datetime.now().strftime("%d/%m/%Y %H:%M:%S")}, grid search complete')

# %%
,
                     ('rf', RandomForestClassifier(random_state=1)),
                     ('lr', LogisticRegression()),
                     ('gb', GradientBoostingClassifier()),
                     ('knn', KNeighborsClassifier()),
                     ('sv', SVC()),
                     ('dt', DecisionTreeClassifier())

# %%
bow_model = search.best_estimator_

bow_model.fit(X_train, y_train)
y_pred = bow_model.predict(X_test)

print(classification_report(y_test, y_pred))
